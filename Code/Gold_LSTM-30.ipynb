# %%
from sentence_to_predicate import WordPredicate
import json
import sentence_grounding_test_parameters as param
import numpy as np
from recognized_object import RecognizedObject

from plots import *
from data_processing import *

import sys
import time
import matplotlib.pyplot as plt
import math
import os
from sklearn.model_selection import KFold
import pandas as pd
from sklearn.metrics import mean_squared_error
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
from tensorflow import keras

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, Masking, GRU
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from transformers import BertModel, BertTokenizer
from transformers import pipeline

# %%
def padding(data_set, max_seq_len = None, special_value = -42):
    if data_set is None:
        return  np.full((1, max_seq_len, nb_unique_words), fill_value=special_value)

    if max_seq_len is None:
        max_seq_len = max([len(s) for s in data_set])

    data_set_pad = np.full((len(data_set), max_seq_len, nb_unique_words), fill_value=special_value)

    for s, x in enumerate(data_set):
        if x is None:
            continue
        seq_len = x.shape[0]
        data_set_pad[s, 0:seq_len, :] = x
    return data_set_pad

# %%
def test_with_sentences(sentences, model):
    global max_seq_len
    test = [one_hot_encoding_sentence(s) for s in sentences]
    #test = []
    test_pad = padding(test, max_seq_len)
    res = model.predict(test_pad)
    return res

# %%
def is_a_valid_imagined_object(predicate, imagined_object):
    """
        Returns whether the predicate description could apply to the imagine_object.

        Inputs:
            predicate: WordPredicate instance
            imagined_object: RecognizedObject instance

    """

    #target = possible_recognized_object_for_predicate(predicate, fill_unkown_fields = False)

    for field in ['category', 'position', 'color']:

        wanted_field = getattr(predicate, field)

        if wanted_field is not None and getattr(imagined_object, field) != wanted_field:
            return False

    return True

def is_a_valid_representation(predicates, imagined_objects):
    """
        Returns whether each predicate  description could apply to its
        corresponding imagined_object.


        Inputs:
            predicates: a list of WordPredicate instances
            imagined_objects: a list of RecognizedObject instance
    """

    return all(map(is_a_valid_imagined_object, predicates, imagined_objects))




def is_an_exact_imagined_object(predicate, imagined_object):
    """
        Returns whether the imagined object matches exactly what the predicate
        describes.

        Inputs:
            predicate: WordPredicate instance
            imagined_object: RecognizedObject instance

    """
    #target = possible_recognized_object_for_predicate(predicate, fill_unkown_fields = False)

    for field in ['category', 'position', 'color']:

        if getattr(imagined_object, field) != getattr(predicate, field):
            return False

    return True

def is_an_exact_representation(predicates, imagined_objects):
    """
        Returns whether the imagined object matches exactly what the predicate
        describes.

        Inputs:
            predicates: a list of WordPredicate instances
            imagined_objects: a list of RecognizedObject instance
    """

    return all(map(is_an_exact_imagined_object, predicates, imagined_objects))

# %%
def generate_labels_valid(sentences):
    words = sentences.replace(".", "").split()
    obj = []
    col = []
    pos = []
    for w in words:
        #print(w)
        if '<'+w+'_obj>' in concepts:
            obj.append('<'+w+'_obj>')
        if '<'+w+'_col>' in concepts:
            col.append('<'+w+'_col>')
        if '<'+w+'_pos>' in concepts:
            pos.append('<'+w+'_pos>')
    ss = ''
    if len(obj)>0:
        if len(pos)>0:
            if len(col)>0:
                return RecognizedObject(obj[0],pos[0],col[0])
            else:
                return RecognizedObject(obj[0],pos[0],None)
        else:
            if len(col)>0:
                return RecognizedObject(obj[0],None,col[0])
            else:
                return RecognizedObject(obj[0],None,None)
    else:
        if len(pos)>0:
            if len(col)>0:
                return RecognizedObject(None,pos[0],col[0])
            else:
                return RecognizedObject(None,pos[0],None)
        else:
            if len(col)>0:
                return RecognizedObject(None,None,col[0])
            else:
                return RecognizedObject(None,None,None)

# %%
def test_on_test_set(model, testX, testY, test_sentences, verbose, threshold_factor):
    test_outputs = model.predict(testX)
    #print(test_outputs[0].shape)
    test_res = model.test_on_batch(testX, testY)
    exact = 0
    valid = 0
    for i in np.arange(len(test_outputs)):
        v = output_to_vision(test_outputs[i],nb_concepts,
                             threshold_factor, concepts_delimitations, output_id_to_concept_dict)
        #pred = sentence_to_pred(sentences[i], sent_to_role)
        pred = []
        clauses = test_sentences[i].split(" and ")
        if len(clauses) == 1:
            if len(test_sentences[i].split("."))>2:
                #print(s.split("."))
                pred.append(generate_labels_valid(test_sentences[i].split(".")[0]))
                pred.append(generate_labels_valid(test_sentences[i].split(".")[1]))
            else:
                pred.append(generate_labels_valid(test_sentences[i]))
                pred.append(RecognizedObject(None,None,None))
        else:
            for j in range(len(clauses)):
                pred.append(generate_labels_valid(clauses[j]))
        #print(v, pred)       
        if is_an_exact_representation(pred, v):
            exact +=1

        if is_a_valid_representation(pred, v):
            valid +=1

        if is_a_valid_representation(pred, v) and not(is_an_exact_representation(pred, v)):
            #print(pred, v, test_outputs[i])
            #print(i)
            pass

    nb_sample = testX.shape[0]
    test_res = mean_squared_error(test_outputs,testY)
    if verbose:
        print("Valid representations : ", valid, "/", nb_sample)
        print("Exact representations : ", exact, "/", nb_sample)
        print("MSE on test : ", test_res)
        print("RMSE on test : ", np.sqrt(test_res))


    return 1-valid/nb_sample, 1-exact/nb_sample, test_res

# %%
## to get the evolution of the loss during training
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        self.exact_errors = []
        self.valid_errors = []

    def on_epoch_end(self, epoch, logs=None):
        global validationX_pad
        global validationY
        self.losses.append(logs.get('loss'))

        v, ex, er = test_on_test_set(self.model, validationX_pad, validationY, validation_sentences, True, 1.3)

        self.val_losses.append(er)
        self.exact_errors.append(ex)
        self.valid_errors.append(v)

    def plot_loss(self):
        plt.figure()
        plt.plot(self.losses, color = "black", label = "loss")
        plt.plot(self.val_losses, color = "red", label = "loss on validation set")
        plt.xlabel("epochs of training")
        plt.title("MSE during training")
        plt.legend()
        plt.show()
        plt.figure()
        plt.title("Performance on validation set during training")
        plt.plot(self.exact_errors, color = "blue", label = "exact error")
        plt.plot(self.valid_errors, color = "green", label = "valid error")
        plt.legend()
        plt.show()

# %%
def get_successive_outputs(sentence, model):
    words = sentence.split(" ")
    prefixes = []
    for i in range(len(words)+1):
        prefixes.append(" ".join(words[:i]))
    print(prefixes)
    vect = test_with_sentences(prefixes[1:], model)
    return vect

# %%
def get_inner_states(sentences, model, only_last = False, info_obj_nb = False):
    all_states = [[] for i in range(len(model.outputs))]

    clause_nbs =[]

    for k in range(len(sentences)):
        states = get_successive_outputs(sentences[k], model)

        if info_obj_nb:
            words = sentences[k].split(" ")
            clause_id = 0
            clause_nbs.append(clause_id)
            for w in words:
                if w == 'and':
                    clause_id +=1
                clause_nbs.append(clause_id)
                if w == 'and':
                    clause_id +=1
            clause_nbs[-1] = 3 #we also mark the final states

        if not(only_last):
            for j in range(len(states)):
                all_states[j].append(states[j])
        else:
            for j in range(len(states)):
                all_states[j].append(states[j][-1] )

    if not(only_last):
        for i in range(len(all_states)):
            all_states[i] = np.concatenate(all_states[i])
    else:
        for i in range(len(all_states)):
            all_states[i] = np.array(all_states[i])

    if info_obj_nb:
        return all_states, np.array(clause_nbs)
    else:
        return all_states

# %%
def plot_hidden_states(sentence, model_for_test, state = 'cell', units_to_plot = 'all', plt_var = False, plt_sum = False):
    activations = get_successive_outputs(sentence, model_for_test)

    plot_hidden_state_activation(sentence,
                                 activations,
                                 state,
                                 units_to_plot,
                                 plot_variation = plt_var,
                                 plot_sum = plt_sum)

# %%
dataset = pd.read_csv('./text.tsv', sep='\t')
dataset.dropna()
dataset.head()
# Out:
#                            hit_id                         worker_id  \
# 0  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 1  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 2  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 3  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 4  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
#
#    worktime_s             item_id  \
# 0         380          potato_3_2
# 1         380      can_opener_4_3
# 2         380  measuring_tape_3_3
# 3         380            fork_3_1
# 4         380      can_opener_3_4
#
#                                                 text
# 0  A single small red skinned potato is laying on...
# 1  The manual can opener has a black plastic hand...
# 2  A pink and black measuring tape is laying on i...
# 3  A silver metal fork is laying with its tines p...
# 4  A manual can opener with a light blue plastic ...

# %%
concepts = []
sentences = []
for i in np.arange(dataset.shape[0]):
    try:
        #print(i.split('_'))
        if len(dataset['item_id'][i].split('_')) == 3:
            concepts.append(dataset['item_id'][i].split('_')[0])
            sentences.append(dataset['text'][i])
        else:
            concepts.append(dataset['item_id'][i].split('_')[0]+" "+dataset['item_id'][i].split('_')[1])
            sentences.append(dataset['text'][i])
        #else:
        #    concepts.append(dataset['item_id'][i].split('_')[0]+dataset['item_id'][i].split('_')[1])
        #    sentences.append(dataset['text'][i].replace(dataset['item_id'][i].split('_')[0]+" "+dataset['item_id'][i].split('_')[1],dataset['item_id'][i].split('_')[0]+dataset['item_id'][i].split('_')[1]))
    except:
        continue

# %%
final_sentences = []
final_concepts = []
for s in sentences:
    try:
        if s.split(" "):
            final_sentences.append(s.lower())
    except:
        print(s)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
object_names = np.random.choice(np.unique(concepts),30, replace=False)

# %%
#object_names = np.unique(concepts)
color_names = ['red', 'black', 'blue', 'green', 'white', 'pink', 'orange', 'yellow']
position_names = ['left', 'right', 'middle', 'top', 'bottom', 'front', 'back']

# %%
final = []
for i in final_sentences:
    for j in object_names:
        if j in i:
            final.append(i)

# %%
def add_object(name, concept = None, build_after = True):
    
    if concept is None:
        concept = '<' + name.lower() + '_obj>'
    
    if name not in OBJECT_NAMES:
        OBJECT_NAMES.append(name)
        
    if concept not in CATEGORIES:
        CATEGORIES.append(concept)
        
    OBJ_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()
    
    
def add_position(name, concept = None, build_after=True):
    
    if concept is None:
        concept = '<' + name.lower() + '_pos>'
    
    if name not in POSITION_NAMES:
        POSITION_NAMES.append(name)
    
    if concept not in POSITIONS:
        POSITIONS.append(concept)
        
    POSITION_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()
       
        
def add_color(name, concept = None, build_after=True):
    
    if concept is None:
        concept = '<' + name.lower() + '_col>'
    
    
    if name not in COLOR_NAMES:
        COLOR_NAMES.append(name)
    
    if concept not in COLORS:
        COLORS.append(concept)
        
    COLOR_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()

# %%
# Words
OBJECT_NAMES = []
COLOR_NAMES = []
POSITION_NAMES = []

# Concepts
CATEGORIES = []
POSITIONS = []
COLORS = []

OBJ_NAME_TO_CONCEPT = dict()
COLOR_NAME_TO_CONCEPT = dict()
POSITION_NAME_TO_CONCEPT = dict()

# %%
for obj in object_names:
    add_object(obj, build_after = False)
        
for col in color_names:
    add_color(col, build_after = False)
        
for pos in position_names:
    add_position(pos, build_after = False)

# %%
################### MAIN #####################

## Parameters

add_begin_end = True #add the word "BEGIN" at the beggining and "END" at the end of all sentences ?
#nb_objects = np.unique(concepts).shape[0] #number of object in the vocabulary used to generate the sentences (the bigger the harder)
nb_objects = 30

special_value = -42 #special value for masking
batch_size = 2
nb_epoch = 70
lstm_units = 80
dropout = 0.2
test_version = True #if we just create a model to do the task (named "model" in the code)
                    #or in addition, create a model to do extensive test to get access to
                    #cell states of the LSTM (named "model_for_test" in the code)

use_save_version = False #use model saved from a previous run
if use_save_version:
    path = r"saved_LSTM/" #path to the model .hdf5 file(s)
    model_id = '0.9144544314163248' #model id (a random float to identify the file(s) of the model save)

threshold_factor = 1.3 # the factor used to get the threshold in the creation of he discrete representation


minimal_mode = False #if minimal mode is on, the model will only be trained and tested on test set. The only text print will be "nb of objects, valid error on test set, exact error on test set, RMSE on test set, time to train"

verbose_training = True

# %%
other_words = []
if add_begin_end:
    other_words.append("BEGIN")
    other_words.append("END")

#init_one_hot_encoding(list(sent_to_role.keys()) + other_words)
#nb_unique_words = len(word2one_hot_id)

# %%
#concept dictionnary initialisation (it's the link between the output position and their meaning)
concepts = CATEGORIES + POSITIONS + COLORS

nb_concepts = len(concepts)

output_size = 2*nb_concepts

concept_to_output_id_dict = {}
output_id_to_concept_dict = {}
for i,c in enumerate(concepts):
    concept_to_output_id_dict[c] = i
    output_id_to_concept_dict[i] = c

# %%
concepts_delimitations = [(0,len(CATEGORIES)),
                          (len(CATEGORIES),
                          len(CATEGORIES) + len(POSITIONS)),
                          (len(CATEGORIES) + len(POSITIONS),
                          len(CATEGORIES) + len(POSITIONS)+ len(COLORS))]

# %%
len(final)
# Out:
# 3629

# %%
##generate data
#we adjust the different dictionnaries to include sentences with BEGIN and END
final_sentences = final
if add_begin_end:
    for i in range(len(final_sentences)):
        final_sentences[i] = "BEGIN "+ final_sentences[i]+ " END"

# %%
#create the training, test and validation set

np.random.shuffle(final_sentences)

train_data = 1000

test_data = 2629

# %%
init_one_hot_encoding(final_sentences + other_words)
nb_unique_words = len(word2one_hot_id)

# %%
train_sentences = (final_sentences[:train_data])


test_sentences = (final_sentences[-test_data:])

# %%
def generate_labels(sen_num, index_num, s):
    words = s.replace(".", "").split()
    for w in words:
        if '<'+w+'_obj>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_obj>')]=1
        if '<'+w+'_col>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_col>')]=1
        if '<'+w+'_pos>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_pos>')]=1

# %%
trainY = np.zeros([len(train_sentences),output_size])
print(trainY.shape)
i = 0
more_objects = []
for s in train_sentences:
    try:
        clauses = s.split(" and ")
        if len(clauses) == 1:
            if len(s.split("."))>2:
                #print(s.split("."))
                generate_labels(i, 0, s.split(".")[0])
                generate_labels(i, len(concepts), s.split(".")[1])
            else:
                generate_labels(i, 0, s)
        else:
            for j in range(len(clauses)):
                generate_labels(i, j*len(concepts), clauses[j])
    except:
        more_objects.append(i)
    i+=1
# Out:
# (1000, 90)

# %%
trainY = np.array(trainY)
trainY = np.delete(trainY,more_objects, axis=0)
print(trainY.shape)

train_sentences = np.array(train_sentences)
train_sentences = np.delete(train_sentences,more_objects, axis=0)
print(train_sentences.shape)
# Out:
# (987, 90)
# (987,)

# %%
def generate_labels_test(sen_num, index_num, s):
    words = s.replace(".", "").split()
    for w in words:
        if '<'+w+'_obj>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_obj>')]=1
        if '<'+w+'_col>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_col>')]=1
        if '<'+w+'_pos>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_pos>')]=1

# %%
testY = np.zeros([len(test_sentences),output_size])
#print(target_output.shape)
i = 0
more_objects_test = []
for s in test_sentences:
    try:
        clauses = s.split(" and ")
        if len(clauses) == 1:
            if len(s.split("."))>2:
                #print(s.split("."))
                generate_labels_test(i, 0, s.split(".")[0])
                generate_labels_test(i, len(concepts), s.split(".")[1])
            else:
                generate_labels_test(i, 0, s)
        else:
            for j in range(len(clauses)):
                generate_labels_test(i, j*len(concepts), clauses[j])
    except:
        more_objects_test.append(i)
    i+=1

# %%
testY = np.array(testY)
testY = np.delete(testY,more_objects_test, axis=0)
print(testY.shape)

test_sentences = np.array(test_sentences)
test_sentences = np.delete(test_sentences,more_objects_test, axis=0)
print(test_sentences.shape)
# Out:
# (2599, 90)
# (2599,)

# %% [raw]
# do_lower_case = True
# model = BertModel.from_pretrained("subbareddyiiit/BERT-NLP", output_attentions=True)
# tokenizer = BertTokenizer.from_pretrained("subbareddyiiit/BERT-NLP", do_lower_case=do_lower_case)
#
# nlp = pipeline('feature-extraction',model=model, tokenizer=tokenizer)

# %%
trainX = [one_hot_encoding_sentence(s) for s in train_sentences]
#trainY = np.array([sentence_to_output_teacher_vector(s,
#                                                     concept_to_output_id_dict,
#                                                     nb_concepts) for s in train_sentences])


testX = [one_hot_encoding_sentence(s) for s in test_sentences]
#testY = np.array([sentence_to_output_teacher_vector(s,
#                                                    sent_to_role,
#                                                    concept_to_output_id_dict,
#                                                    nb_concepts) for s in test_sentences])

# %% [raw]
# trainX = []
# for s in train_sentences:
#     temp = []
#     for w in s.split():
#         temp.append(np.mean(np.array(nlp(w)),axis=1))
#     temp = np.array(temp)
#     temp = np.reshape(temp,(temp.shape[0]*temp.shape[1], temp.shape[2]))
#     #temp = np.mean(temp, axis=1)
#     #print(np.mean(temp, axis=1).shape)
#     #print(temp.shape)
#     trainX.append(temp)

# %% [raw]
# testX = []
# for s in test_sentences:
#     temp = []
#     for w in s.split():
#         temp.append(np.mean(np.array(nlp(w)),axis=1))
#     temp = np.array(temp)
#     temp = np.reshape(temp,(temp.shape[0]*temp.shape[1], temp.shape[2]))
#     #temp = np.mean(temp, axis=1)
#     #print(np.mean(temp, axis=1).shape)
#     #print(temp.shape)
#     testX.append(temp)

# %%
#create the training, test and validation set
validationX = testX[2300:]
validationY = testY[2300:]
validation_sentences = test_sentences[2300:]

# %%
#nb_unique_words=768
max_seq_len = max([len(s.split(" ")) for s in final_sentences])

trainX_pad = padding(trainX,max_seq_len = max_seq_len)
testX_pad = padding(testX, max_seq_len = max_seq_len)
validationX_pad = padding(validationX, max_seq_len = max_seq_len)

# %%
print(trainX_pad.shape, testX_pad.shape, validationX_pad.shape)
# Out:
# (987, 56, 1953) (2599, 56, 1953) (299, 56, 1953)

# %%
CONCEPT_LISTS = [
            CATEGORIES,
            POSITIONS,
            COLORS
            ]
def plot_concept_activation(sentence, activations, concepts_delim,nb_concepts, output_function = None, savefig=False, sub_ttl_fig='', ylims=(-0.4, 1.4)):
    """
        Plots activation through time of the different concepts while hearing
        the sentence. If output_function is not None, it is applied to the reservoir
        output vector before plotting.
        This is a reuse of a function developped by Alexis Juven.
    """

    outputs = activations.copy()
    activation_threshold = 0.5

    if output_function is not None:

        activation_threshold = output_function(activation_threshold)

        for i in range(outputs.shape[0]):
            outputs[i, :] = output_function(outputs[i, :])


    words = sentence.split(" ")
    max_nb_seen_objects = 2
    nb_object_properties = 3

    fig, axes = plt.subplots(nb_object_properties, max_nb_seen_objects, figsize=(25,20))


    concept_delimitations = [t[0] for t in concepts_delim] + [concepts_delim[-1][1]]

    for i in range(max_nb_seen_objects):

        offset = i * nb_concepts

        axes[0, i].set_title("Object " + str(i+1), fontsize = 22)

        for j in range(nb_object_properties):

            ax = axes[j, i]
            ax.plot(outputs[:, offset + concept_delimitations[j] : offset + concept_delimitations[j+1]], linewidth = 4)
            ax.legend(CONCEPT_LISTS[j], loc = 2, fontsize = 22)

            ax.set_yticks([0., 0.5, 1.])
            ax.set_yticklabels([0., 0.5, 1.], fontsize = 20)

            ax.set_ylim([ylims[0], ylims[1]])

            ax.set_xticks(np.arange(len(words)))
            ax.set_xticklabels(words, fontsize = 24)
            # Rotate the tick labels and set their alignment.
            plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor", fontsize = 22)

            ax.plot(len(words) * [activation_threshold], '--', color = 'grey', linewidth = 3)

    fig.suptitle(sentence, fontsize = 26)
    plt.subplots_adjust(hspace = 0.3)

    if savefig:
        plt.savefig('sentence_'+sub_ttl_fig+".png", bbox_inches='tight')
        plt.close()
    else:
        fig.show()
        #plt.show()

# %%
for _ in np.arange(1):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, dropout = dropout)(masked)

                    output_to_train = Dense(output_size)(lstm_out)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[0:2300] , testY[0:2300], test_sentences[0:2300], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking (Masking)            (None, 56, 1953)          0
# _________________________________________________________________
# lstm (LSTM)                  [(None, 20), (None, 20),  157920
# _________________________________________________________________
# dense (Dense)                (None, 90)                1890
# =================================================================
# Total params: 159,810
# Trainable params: 159,810
# Non-trainable params: 0
# _________________________________________________________________
# model for hidden states:  None
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking (Masking)            (None, 56, 1953)          0
# _________________________________________________________________
# lstm (LSTM)                  [(None, 20), (None, 20),  157920
# _________________________________________________________________
# dense (Dense)                (None, 90)                1890
# =================================================================
# Total params: 159,810
# Trainable params: 159,810
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  22 / 299
# Exact representations :  22 / 299
# MSE on test :  0.015301772381031205
# RMSE on test :  0.12370033298674343
#
# Epoch 00001: val_loss improved from inf to 0.01530, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 16s - loss: 0.0171 - val_loss: 0.0153
# Epoch 2/70
# Valid representations :  90 / 299
# Exact representations :  89 / 299
# MSE on test :  0.012722773026717404
# RMSE on test :  0.11279527040934564
#
# Epoch 00002: val_loss improved from 0.01530 to 0.01272, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0140 - val_loss: 0.0127
# Epoch 3/70
# Valid representations :  125 / 299
# Exact representations :  123 / 299
# MSE on test :  0.011493411210187987
# RMSE on test :  0.10720732815525245
#
# Epoch 00003: val_loss improved from 0.01272 to 0.01149, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0121 - val_loss: 0.0115
# Epoch 4/70
# Valid representations :  135 / 299
# Exact representations :  133 / 299
# MSE on test :  0.010766846157355243
# RMSE on test :  0.10376341434896619
#
# Epoch 00004: val_loss improved from 0.01149 to 0.01077, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0110 - val_loss: 0.0108
# Epoch 5/70
# Valid representations :  152 / 299
# Exact representations :  149 / 299
# MSE on test :  0.010242474129034888
# RMSE on test :  0.10120510920420416
#
# Epoch 00005: val_loss improved from 0.01077 to 0.01024, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0101 - val_loss: 0.0102
# Epoch 6/70
# Valid representations :  165 / 299
# Exact representations :  162 / 299
# MSE on test :  0.009919925627458975
# RMSE on test :  0.0995988234240695
#
# Epoch 00006: val_loss improved from 0.01024 to 0.00992, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0095 - val_loss: 0.0099
# Epoch 7/70
# Valid representations :  182 / 299
# Exact representations :  178 / 299
# MSE on test :  0.009657969343797083
# RMSE on test :  0.09827496804271718
#
# Epoch 00007: val_loss improved from 0.00992 to 0.00966, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0092 - val_loss: 0.0097
# Epoch 8/70
# Valid representations :  183 / 299
# Exact representations :  180 / 299
# MSE on test :  0.009505234212583577
# RMSE on test :  0.09749479069459853
#
# Epoch 00008: val_loss improved from 0.00966 to 0.00951, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0089 - val_loss: 0.0095
# Epoch 9/70
# Valid representations :  190 / 299
# Exact representations :  185 / 299
# MSE on test :  0.009295764829147617
# RMSE on test :  0.09641454677146813
#
# Epoch 00009: val_loss improved from 0.00951 to 0.00930, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0086 - val_loss: 0.0093
# Epoch 10/70
# Valid representations :  191 / 299
# Exact representations :  186 / 299
# MSE on test :  0.009224974709994454
# RMSE on test :  0.09604673190689236
#
# Epoch 00010: val_loss improved from 0.00930 to 0.00922, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0083 - val_loss: 0.0092
# Epoch 11/70
# Valid representations :  188 / 299
# Exact representations :  179 / 299
# MSE on test :  0.009198068776051492
# RMSE on test :  0.09590656273713229
#
# Epoch 00011: val_loss improved from 0.00922 to 0.00920, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0082 - val_loss: 0.0092
# Epoch 12/70
# Valid representations :  191 / 299
# Exact representations :  183 / 299
# MSE on test :  0.00899776243726247
# RMSE on test :  0.09485653608087569
#
# Epoch 00012: val_loss improved from 0.00920 to 0.00900, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0081 - val_loss: 0.0090
# Epoch 13/70
# Valid representations :  191 / 299
# Exact representations :  185 / 299
# MSE on test :  0.008981538996959065
# RMSE on test :  0.09477098182966696
#
# Epoch 00013: val_loss improved from 0.00900 to 0.00898, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0080 - val_loss: 0.0090
# Epoch 14/70
# Valid representations :  191 / 299
# Exact representations :  186 / 299
# MSE on test :  0.008945920981758301
# RMSE on test :  0.09458287890394487
#
# Epoch 00014: val_loss improved from 0.00898 to 0.00895, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0079 - val_loss: 0.0089
# Epoch 15/70
# Valid representations :  191 / 299
# Exact representations :  185 / 299
# MSE on test :  0.008929721235476014
# RMSE on test :  0.09449720226269143
#
# Epoch 00015: val_loss improved from 0.00895 to 0.00893, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0078 - val_loss: 0.0089
# Epoch 16/70
# Valid representations :  195 / 299
# Exact representations :  187 / 299
# MSE on test :  0.008823328878975611
# RMSE on test :  0.09393257623942618
#
# Epoch 00016: val_loss improved from 0.00893 to 0.00882, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0078 - val_loss: 0.0088
# Epoch 17/70
# Valid representations :  198 / 299
# Exact representations :  190 / 299
# MSE on test :  0.008808115435340177
# RMSE on test :  0.09385156064413727
#
# Epoch 00017: val_loss improved from 0.00882 to 0.00881, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0076 - val_loss: 0.0088
# Epoch 18/70
# Valid representations :  196 / 299
# Exact representations :  186 / 299
# MSE on test :  0.008803570556253542
# RMSE on test :  0.09382734439518974
#
# Epoch 00018: val_loss improved from 0.00881 to 0.00880, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 13s - loss: 0.0076 - val_loss: 0.0088
# Epoch 19/70
# Valid representations :  201 / 299
# Exact representations :  191 / 299
# MSE on test :  0.008710558320565932
# RMSE on test :  0.09333037190843038
#
# Epoch 00019: val_loss improved from 0.00880 to 0.00871, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0074 - val_loss: 0.0087
# Epoch 20/70
# Valid representations :  196 / 299
# Exact representations :  187 / 299
# MSE on test :  0.008663644453353502
# RMSE on test :  0.0930787003205003
#
# Epoch 00020: val_loss improved from 0.00871 to 0.00866, saving model to saved_LSTM/best_model0.4618443031923791.hdf5
# 494/494 - 12s - loss: 0.0073 - val_loss: 0.0087
# Epoch 21/70
# Valid representations :  195 / 299
# Exact representations :  186 / 299
# MSE on test :  0.008789737579367537
# RMSE on test :  0.09375360035415993
#
# Epoch 00021: val_loss did not improve from 0.00866
# 494/494 - 12s - loss: 0.0074 - val_loss: 0.0088
# Epoch 22/70
# Valid representations :  197 / 299
# Exact representations :  189 / 299
# MSE on test :  0.008668196689315132
# RMSE on test :  0.09310315080229634
#
# Epoch 00022: val_loss did not improve from 0.00866
# 494/494 - 12s - loss: 0.0072 - val_loss: 0.0087
# Epoch 23/70
# Valid representations :  197 / 299
# Exact representations :  185 / 299
# MSE on test :  0.008671532576045325
# RMSE on test :  0.0931210640835108
#
# Epoch 00023: val_loss did not improve from 0.00866
# 494/494 - 12s - loss: 0.0073 - val_loss: 0.0087
# Epoch 24/70
# Valid representations :  197 / 299
# Exact representations :  185 / 299
# MSE on test :  0.008705541082172273
# RMSE on test :  0.09330348912110561
#
# Epoch 00024: val_loss did not improve from 0.00866
# 494/494 - 12s - loss: 0.0075 - val_loss: 0.0087
# Epoch 25/70
# Valid representations :  199 / 299
# Exact representations :  187 / 299
# MSE on test :  0.008680789593201435
# RMSE on test :  0.09317075503183087
#
# Epoch 00025: val_loss did not improve from 0.00866
# 494/494 - 13s - loss: 0.0072 - val_loss: 0.0087
# Epoch 00025: early stopping
# End of training !
# CPU Time to train :  1092.200606453
# Testing on test set ...
# Valid representations :  1595 / 2300
# Exact representations :  1503 / 2300
# MSE on test :  0.008224331226018561
# RMSE on test :  0.0906880985908215
# Testing on training set ...
# Valid representations :  763 / 987
# Exact representations :  734 / 987
# MSE on test :  0.0057937647380816104
# RMSE on test :  0.07611678355055218
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for _ in np.arange(1):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, dropout = dropout)(masked)

                    output_to_train = Dense(output_size)(lstm_out)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[300:] , testY[300:], test_sentences[300:], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking_1 (Masking)          (None, 56, 1953)          0
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 40), (None, 40),  319040
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                3690
# =================================================================
# Total params: 322,730
# Trainable params: 322,730
# Non-trainable params: 0
# _________________________________________________________________
# model for hidden states:  None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking_1 (Masking)          (None, 56, 1953)          0
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 40), (None, 40),  319040
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                3690
# =================================================================
# Total params: 322,730
# Trainable params: 322,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  43 / 299
# Exact representations :  43 / 299
# MSE on test :  0.014215806532391143
# RMSE on test :  0.119230057168447
#
# Epoch 00001: val_loss improved from inf to 0.01422, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 12s - loss: 0.0167 - val_loss: 0.0142
# Epoch 2/70
# Valid representations :  128 / 299
# Exact representations :  127 / 299
# MSE on test :  0.011197021413119729
# RMSE on test :  0.10581597900657409
#
# Epoch 00002: val_loss improved from 0.01422 to 0.01120, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 10s - loss: 0.0125 - val_loss: 0.0112
# Epoch 3/70
# Valid representations :  176 / 299
# Exact representations :  173 / 299
# MSE on test :  0.009785942787996068
# RMSE on test :  0.09892392424482598
#
# Epoch 00003: val_loss improved from 0.01120 to 0.00979, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0102 - val_loss: 0.0098
# Epoch 4/70
# Valid representations :  192 / 299
# Exact representations :  185 / 299
# MSE on test :  0.008874598066855317
# RMSE on test :  0.09420508514329425
#
# Epoch 00004: val_loss improved from 0.00979 to 0.00887, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0088 - val_loss: 0.0089
# Epoch 5/70
# Valid representations :  200 / 299
# Exact representations :  187 / 299
# MSE on test :  0.008407529931613431
# RMSE on test :  0.09169258384195218
#
# Epoch 00005: val_loss improved from 0.00887 to 0.00841, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0080 - val_loss: 0.0084
# Epoch 6/70
# Valid representations :  214 / 299
# Exact representations :  193 / 299
# MSE on test :  0.008016682783485485
# RMSE on test :  0.08953593012576284
#
# Epoch 00006: val_loss improved from 0.00841 to 0.00802, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0073 - val_loss: 0.0080
# Epoch 7/70
# Valid representations :  215 / 299
# Exact representations :  199 / 299
# MSE on test :  0.007729006418524605
# RMSE on test :  0.08791476792055249
#
# Epoch 00007: val_loss improved from 0.00802 to 0.00773, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 15s - loss: 0.0069 - val_loss: 0.0077
# Epoch 8/70
# Valid representations :  219 / 299
# Exact representations :  206 / 299
# MSE on test :  0.007486122188654876
# RMSE on test :  0.08652237969828891
#
# Epoch 00008: val_loss improved from 0.00773 to 0.00749, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0065 - val_loss: 0.0075
# Epoch 9/70
# Valid representations :  227 / 299
# Exact representations :  209 / 299
# MSE on test :  0.0072229324479865875
# RMSE on test :  0.08498783705911445
#
# Epoch 00009: val_loss improved from 0.00749 to 0.00722, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0064 - val_loss: 0.0072
# Epoch 10/70
# Valid representations :  233 / 299
# Exact representations :  217 / 299
# MSE on test :  0.007137782467936425
# RMSE on test :  0.08448539795690392
#
# Epoch 00010: val_loss improved from 0.00722 to 0.00714, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0060 - val_loss: 0.0071
# Epoch 11/70
# Valid representations :  231 / 299
# Exact representations :  213 / 299
# MSE on test :  0.0070512891385465975
# RMSE on test :  0.08397195447616185
#
# Epoch 00011: val_loss improved from 0.00714 to 0.00705, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0058 - val_loss: 0.0071
# Epoch 12/70
# Valid representations :  233 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006820481648750416
# RMSE on test :  0.08258620737599237
#
# Epoch 00012: val_loss improved from 0.00705 to 0.00682, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 13s - loss: 0.0057 - val_loss: 0.0068
# Epoch 13/70
# Valid representations :  235 / 299
# Exact representations :  211 / 299
# MSE on test :  0.006727929712725018
# RMSE on test :  0.08202395816299661
#
# Epoch 00013: val_loss improved from 0.00682 to 0.00673, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0054 - val_loss: 0.0067
# Epoch 14/70
# Valid representations :  234 / 299
# Exact representations :  214 / 299
# MSE on test :  0.0066504860597410426
# RMSE on test :  0.08155051232053077
#
# Epoch 00014: val_loss improved from 0.00673 to 0.00665, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0051 - val_loss: 0.0067
# Epoch 15/70
# Valid representations :  237 / 299
# Exact representations :  209 / 299
# MSE on test :  0.00664744822988649
# RMSE on test :  0.08153188474386257
#
# Epoch 00015: val_loss improved from 0.00665 to 0.00665, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 15s - loss: 0.0051 - val_loss: 0.0066
# Epoch 16/70
# Valid representations :  232 / 299
# Exact representations :  212 / 299
# MSE on test :  0.006549170369266214
# RMSE on test :  0.08092694464309284
#
# Epoch 00016: val_loss improved from 0.00665 to 0.00655, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0050 - val_loss: 0.0065
# Epoch 17/70
# Valid representations :  238 / 299
# Exact representations :  219 / 299
# MSE on test :  0.00644376431745269
# RMSE on test :  0.08027306096974682
#
# Epoch 00017: val_loss improved from 0.00655 to 0.00644, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0050 - val_loss: 0.0064
# Epoch 18/70
# Valid representations :  236 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006548189773946056
# RMSE on test :  0.08092088589447137
#
# Epoch 00018: val_loss did not improve from 0.00644
# 494/494 - 14s - loss: 0.0047 - val_loss: 0.0065
# Epoch 19/70
# Valid representations :  236 / 299
# Exact representations :  212 / 299
# MSE on test :  0.00642199199253135
# RMSE on test :  0.08013733207769866
#
# Epoch 00019: val_loss improved from 0.00644 to 0.00642, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0047 - val_loss: 0.0064
# Epoch 20/70
# Valid representations :  236 / 299
# Exact representations :  213 / 299
# MSE on test :  0.006473415875577617
# RMSE on test :  0.08045754082482025
#
# Epoch 00020: val_loss did not improve from 0.00642
# 494/494 - 14s - loss: 0.0048 - val_loss: 0.0065
# Epoch 21/70
# Valid representations :  240 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006324903365409091
# RMSE on test :  0.07952926106414601
#
# Epoch 00021: val_loss improved from 0.00642 to 0.00632, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0046 - val_loss: 0.0063
# Epoch 22/70
# Valid representations :  239 / 299
# Exact representations :  212 / 299
# MSE on test :  0.0062995356339149875
# RMSE on test :  0.07936961404665509
#
# Epoch 00022: val_loss improved from 0.00632 to 0.00630, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0043 - val_loss: 0.0063
# Epoch 23/70
# Valid representations :  242 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006197488391783505
# RMSE on test :  0.07872412839646753
#
# Epoch 00023: val_loss improved from 0.00630 to 0.00620, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0044 - val_loss: 0.0062
# Epoch 24/70
# Valid representations :  241 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006183883150605655
# RMSE on test :  0.0786376700481751
#
# Epoch 00024: val_loss improved from 0.00620 to 0.00618, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0045 - val_loss: 0.0062
# Epoch 25/70
# Valid representations :  242 / 299
# Exact representations :  216 / 299
# MSE on test :  0.006113290980716957
# RMSE on test :  0.07818753724678222
#
# Epoch 00025: val_loss improved from 0.00618 to 0.00611, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 13s - loss: 0.0043 - val_loss: 0.0061
# Epoch 26/70
# Valid representations :  245 / 299
# Exact representations :  219 / 299
# MSE on test :  0.006085064842185067
# RMSE on test :  0.07800682561279536
#
# Epoch 00026: val_loss improved from 0.00611 to 0.00609, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 13s - loss: 0.0043 - val_loss: 0.0061
# Epoch 27/70
# Valid representations :  240 / 299
# Exact representations :  213 / 299
# MSE on test :  0.006045191702440783
# RMSE on test :  0.07775083087942394
#
# Epoch 00027: val_loss improved from 0.00609 to 0.00605, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 14s - loss: 0.0042 - val_loss: 0.0060
# Epoch 28/70
# Valid representations :  243 / 299
# Exact representations :  219 / 299
# MSE on test :  0.006037692299068309
# RMSE on test :  0.07770258875396822
#
# Epoch 00028: val_loss improved from 0.00605 to 0.00604, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0043 - val_loss: 0.0060
# Epoch 29/70
# Valid representations :  243 / 299
# Exact representations :  214 / 299
# MSE on test :  0.005999012476820345
# RMSE on test :  0.0774532922271245
#
# Epoch 00029: val_loss improved from 0.00604 to 0.00600, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0040 - val_loss: 0.0060
# Epoch 30/70
# Valid representations :  243 / 299
# Exact representations :  213 / 299
# MSE on test :  0.006111098955689596
# RMSE on test :  0.07817351825068126
#
# Epoch 00030: val_loss did not improve from 0.00600
# 494/494 - 9s - loss: 0.0040 - val_loss: 0.0061
# Epoch 31/70
# Valid representations :  245 / 299
# Exact representations :  216 / 299
# MSE on test :  0.006048808320639015
# RMSE on test :  0.07777408514819711
#
# Epoch 00031: val_loss did not improve from 0.00600
# 494/494 - 9s - loss: 0.0041 - val_loss: 0.0060
# Epoch 32/70
# Valid representations :  246 / 299
# Exact representations :  216 / 299
# MSE on test :  0.005912114926859724
# RMSE on test :  0.07689027849383642
#
# Epoch 00032: val_loss improved from 0.00600 to 0.00591, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0039 - val_loss: 0.0059
# Epoch 33/70
# Valid representations :  244 / 299
# Exact representations :  213 / 299
# MSE on test :  0.006082282996858453
# RMSE on test :  0.07798899279294773
#
# Epoch 00033: val_loss did not improve from 0.00591
# 494/494 - 9s - loss: 0.0040 - val_loss: 0.0061
# Epoch 34/70
# Valid representations :  246 / 299
# Exact representations :  216 / 299
# MSE on test :  0.00590384771433436
# RMSE on test :  0.07683649988341713
#
# Epoch 00034: val_loss improved from 0.00591 to 0.00590, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0040 - val_loss: 0.0059
# Epoch 35/70
# Valid representations :  243 / 299
# Exact representations :  217 / 299
# MSE on test :  0.0059214280015041955
# RMSE on test :  0.07695081547004032
#
# Epoch 00035: val_loss did not improve from 0.00590
# 494/494 - 9s - loss: 0.0039 - val_loss: 0.0059
# Epoch 36/70
# Valid representations :  244 / 299
# Exact representations :  215 / 299
# MSE on test :  0.005908701794393766
# RMSE on test :  0.07686808046513043
#
# Epoch 00036: val_loss did not improve from 0.00590
# 494/494 - 9s - loss: 0.0039 - val_loss: 0.0059
# Epoch 37/70
# Valid representations :  243 / 299
# Exact representations :  212 / 299
# MSE on test :  0.005909649293154058
# RMSE on test :  0.07687424336638415
#
# Epoch 00037: val_loss did not improve from 0.00590
# 494/494 - 9s - loss: 0.0038 - val_loss: 0.0059
# Epoch 38/70
# Valid representations :  248 / 299
# Exact representations :  218 / 299
# MSE on test :  0.005882946204392457
# RMSE on test :  0.07670036639021001
#
# Epoch 00038: val_loss improved from 0.00590 to 0.00588, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0037 - val_loss: 0.0059
# Epoch 39/70
# Valid representations :  247 / 299
# Exact representations :  217 / 299
# MSE on test :  0.005866958406534853
# RMSE on test :  0.0765960730490464
#
# Epoch 00039: val_loss improved from 0.00588 to 0.00587, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0036 - val_loss: 0.0059
# Epoch 40/70
# Valid representations :  246 / 299
# Exact representations :  217 / 299
# MSE on test :  0.005737759877472902
# RMSE on test :  0.07574800246523272
#
# Epoch 00040: val_loss improved from 0.00587 to 0.00574, saving model to saved_LSTM/best_model0.6512549562149517.hdf5
# 494/494 - 9s - loss: 0.0038 - val_loss: 0.0057
# Epoch 41/70
# Valid representations :  248 / 299
# Exact representations :  214 / 299
# MSE on test :  0.005768143599193052
# RMSE on test :  0.07594829556476598
#
# Epoch 00041: val_loss did not improve from 0.00574
# 494/494 - 9s - loss: 0.0038 - val_loss: 0.0058
# Epoch 42/70
# Valid representations :  248 / 299
# Exact representations :  215 / 299
# MSE on test :  0.005759784254265096
# RMSE on test :  0.07589324248090272
#
# Epoch 00042: val_loss did not improve from 0.00574
# 494/494 - 9s - loss: 0.0038 - val_loss: 0.0058
# Epoch 43/70
# Valid representations :  247 / 299
# Exact representations :  213 / 299
# MSE on test :  0.005857855338267283
# RMSE on test :  0.07653662742940326
#
# Epoch 00043: val_loss did not improve from 0.00574
# 494/494 - 9s - loss: 0.0037 - val_loss: 0.0059
# Epoch 44/70
# Valid representations :  247 / 299
# Exact representations :  216 / 299
# MSE on test :  0.0057448088012762135
# RMSE on test :  0.07579451696050456
#
# Epoch 00044: val_loss did not improve from 0.00574
# 494/494 - 9s - loss: 0.0035 - val_loss: 0.0057
# Epoch 45/70
# Valid representations :  251 / 299
# Exact representations :  216 / 299
# MSE on test :  0.005769833758056405
# RMSE on test :  0.07595942178595362
#
# Epoch 00045: val_loss did not improve from 0.00574
# 494/494 - 9s - loss: 0.0038 - val_loss: 0.0058
# Epoch 00045: early stopping
# End of training !
# CPU Time to train :  2460.064878493
# Testing on test set ...
# Valid representations :  1912 / 2299
# Exact representations :  1696 / 2299
# MSE on test :  0.005432281290756395
# RMSE on test :  0.07370401136136619
# Testing on training set ...
# Valid representations :  902 / 987
# Exact representations :  890 / 987
# MSE on test :  0.0018384324464521496
# RMSE on test :  0.04287694539554036
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for _ in np.arange(1):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, dropout = dropout)(masked)

                    output_to_train = Dense(output_size)(lstm_out)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[300:] , testY[300:], test_sentences[300:], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking_2 (Masking)          (None, 56, 1953)          0
# _________________________________________________________________
# lstm_2 (LSTM)                [(None, 80), (None, 80),  650880
# _________________________________________________________________
# dense_2 (Dense)              (None, 90)                7290
# =================================================================
# Total params: 658,170
# Trainable params: 658,170
# Non-trainable params: 0
# _________________________________________________________________
# model for hidden states:  None
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 56, 1953)]        0
# _________________________________________________________________
# masking_2 (Masking)          (None, 56, 1953)          0
# _________________________________________________________________
# lstm_2 (LSTM)                [(None, 80), (None, 80),  650880
# _________________________________________________________________
# dense_2 (Dense)              (None, 90)                7290
# =================================================================
# Total params: 658,170
# Trainable params: 658,170
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  94 / 299
# Exact representations :  94 / 299
# MSE on test :  0.012379445819279505
# RMSE on test :  0.11126295798368613
#
# Epoch 00001: val_loss improved from inf to 0.01238, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 14s - loss: 0.0156 - val_loss: 0.0124
# Epoch 2/70
# Valid representations :  174 / 299
# Exact representations :  171 / 299
# MSE on test :  0.009697900533590088
# RMSE on test :  0.09847791901533098
#
# Epoch 00002: val_loss improved from 0.01238 to 0.00970, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0110 - val_loss: 0.0097
# Epoch 3/70
# Valid representations :  199 / 299
# Exact representations :  196 / 299
# MSE on test :  0.008436495451811988
# RMSE on test :  0.09185039712386653
#
# Epoch 00003: val_loss improved from 0.00970 to 0.00844, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 12s - loss: 0.0087 - val_loss: 0.0084
# Epoch 4/70
# Valid representations :  210 / 299
# Exact representations :  195 / 299
# MSE on test :  0.007918051608983503
# RMSE on test :  0.08898343446385683
#
# Epoch 00004: val_loss improved from 0.00844 to 0.00792, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 12s - loss: 0.0077 - val_loss: 0.0079
# Epoch 5/70
# Valid representations :  217 / 299
# Exact representations :  206 / 299
# MSE on test :  0.007434965206329374
# RMSE on test :  0.086226244301427
#
# Epoch 00005: val_loss improved from 0.00792 to 0.00743, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 14s - loss: 0.0070 - val_loss: 0.0074
# Epoch 6/70
# Valid representations :  227 / 299
# Exact representations :  207 / 299
# MSE on test :  0.007346909079286932
# RMSE on test :  0.08571411248614158
#
# Epoch 00006: val_loss improved from 0.00743 to 0.00735, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0064 - val_loss: 0.0073
# Epoch 7/70
# Valid representations :  231 / 299
# Exact representations :  210 / 299
# MSE on test :  0.007028953806959012
# RMSE on test :  0.0838388561882795
#
# Epoch 00007: val_loss improved from 0.00735 to 0.00703, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0061 - val_loss: 0.0070
# Epoch 8/70
# Valid representations :  232 / 299
# Exact representations :  206 / 299
# MSE on test :  0.00691733185093713
# RMSE on test :  0.08317049868154651
#
# Epoch 00008: val_loss improved from 0.00703 to 0.00692, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0058 - val_loss: 0.0069
# Epoch 9/70
# Valid representations :  236 / 299
# Exact representations :  210 / 299
# MSE on test :  0.006720912140765659
# RMSE on test :  0.08198116942789764
#
# Epoch 00009: val_loss improved from 0.00692 to 0.00672, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0053 - val_loss: 0.0067
# Epoch 10/70
# Valid representations :  239 / 299
# Exact representations :  214 / 299
# MSE on test :  0.006605891132679576
# RMSE on test :  0.08127663337441811
#
# Epoch 00010: val_loss improved from 0.00672 to 0.00661, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0052 - val_loss: 0.0066
# Epoch 11/70
# Valid representations :  240 / 299
# Exact representations :  214 / 299
# MSE on test :  0.006565057996842945
# RMSE on test :  0.08102504549115011
#
# Epoch 00011: val_loss improved from 0.00661 to 0.00657, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0050 - val_loss: 0.0066
# Epoch 12/70
# Valid representations :  243 / 299
# Exact representations :  212 / 299
# MSE on test :  0.006328608943365134
# RMSE on test :  0.07955255459986897
#
# Epoch 00012: val_loss improved from 0.00657 to 0.00633, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 13s - loss: 0.0047 - val_loss: 0.0063
# Epoch 13/70
# Valid representations :  242 / 299
# Exact representations :  217 / 299
# MSE on test :  0.006429855243031363
# RMSE on test :  0.08018637816382133
#
# Epoch 00013: val_loss did not improve from 0.00633
# 494/494 - 18s - loss: 0.0047 - val_loss: 0.0064
# Epoch 14/70
# Valid representations :  242 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006229861971875487
# RMSE on test :  0.0789294746712246
#
# Epoch 00014: val_loss improved from 0.00633 to 0.00623, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 26s - loss: 0.0045 - val_loss: 0.0062
# Epoch 15/70
# Valid representations :  243 / 299
# Exact representations :  201 / 299
# MSE on test :  0.006219618362236495
# RMSE on test :  0.07886455707246758
#
# Epoch 00015: val_loss improved from 0.00623 to 0.00622, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 24s - loss: 0.0044 - val_loss: 0.0062
# Epoch 16/70
# Valid representations :  241 / 299
# Exact representations :  210 / 299
# MSE on test :  0.006223569890521361
# RMSE on test :  0.07888960571913996
#
# Epoch 00016: val_loss did not improve from 0.00622
# 494/494 - 24s - loss: 0.0044 - val_loss: 0.0062
# Epoch 17/70
# Valid representations :  238 / 299
# Exact representations :  211 / 299
# MSE on test :  0.006088658961921085
# RMSE on test :  0.07802985942522955
#
# Epoch 00017: val_loss improved from 0.00622 to 0.00609, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0040 - val_loss: 0.0061
# Epoch 18/70
# Valid representations :  245 / 299
# Exact representations :  213 / 299
# MSE on test :  0.006136704291229692
# RMSE on test :  0.07833711949790911
#
# Epoch 00018: val_loss did not improve from 0.00609
# 494/494 - 25s - loss: 0.0042 - val_loss: 0.0061
# Epoch 19/70
# Valid representations :  244 / 299
# Exact representations :  215 / 299
# MSE on test :  0.006078534123362503
# RMSE on test :  0.07796495445623311
#
# Epoch 00019: val_loss improved from 0.00609 to 0.00608, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0038 - val_loss: 0.0061
# Epoch 20/70
# Valid representations :  247 / 299
# Exact representations :  213 / 299
# MSE on test :  0.00604609950304551
# RMSE on test :  0.07775666854389732
#
# Epoch 00020: val_loss improved from 0.00608 to 0.00605, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0039 - val_loss: 0.0060
# Epoch 21/70
# Valid representations :  242 / 299
# Exact representations :  217 / 299
# MSE on test :  0.006017653435176495
# RMSE on test :  0.07757353566246994
#
# Epoch 00021: val_loss improved from 0.00605 to 0.00602, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0040 - val_loss: 0.0060
# Epoch 22/70
# Valid representations :  249 / 299
# Exact representations :  213 / 299
# MSE on test :  0.005989344657235029
# RMSE on test :  0.07739085641879814
#
# Epoch 00022: val_loss improved from 0.00602 to 0.00599, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0039 - val_loss: 0.0060
# Epoch 23/70
# Valid representations :  248 / 299
# Exact representations :  221 / 299
# MSE on test :  0.005968610964514161
# RMSE on test :  0.07725678588003879
#
# Epoch 00023: val_loss improved from 0.00599 to 0.00597, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 26s - loss: 0.0038 - val_loss: 0.0060
# Epoch 24/70
# Valid representations :  247 / 299
# Exact representations :  217 / 299
# MSE on test :  0.005991169646394723
# RMSE on test :  0.07740264624930289
#
# Epoch 00024: val_loss did not improve from 0.00597
# 494/494 - 25s - loss: 0.0036 - val_loss: 0.0060
# Epoch 25/70
# Valid representations :  251 / 299
# Exact representations :  222 / 299
# MSE on test :  0.005812082607871728
# RMSE on test :  0.0762370159953269
#
# Epoch 00025: val_loss improved from 0.00597 to 0.00581, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 24s - loss: 0.0037 - val_loss: 0.0058
# Epoch 26/70
# Valid representations :  250 / 299
# Exact representations :  219 / 299
# MSE on test :  0.005802253822869562
# RMSE on test :  0.07617252669348419
#
# Epoch 00026: val_loss improved from 0.00581 to 0.00580, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 26s - loss: 0.0037 - val_loss: 0.0058
# Epoch 27/70
# Valid representations :  250 / 299
# Exact representations :  223 / 299
# MSE on test :  0.005795242652709857
# RMSE on test :  0.07612649113619947
#
# Epoch 00027: val_loss improved from 0.00580 to 0.00580, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0033 - val_loss: 0.0058
# Epoch 28/70
# Valid representations :  251 / 299
# Exact representations :  224 / 299
# MSE on test :  0.005818347780066294
# RMSE on test :  0.07627809502122018
#
# Epoch 00028: val_loss did not improve from 0.00580
# 494/494 - 26s - loss: 0.0033 - val_loss: 0.0058
# Epoch 29/70
# Valid representations :  253 / 299
# Exact representations :  222 / 299
# MSE on test :  0.005776346845325742
# RMSE on test :  0.07600228184288772
#
# Epoch 00029: val_loss improved from 0.00580 to 0.00578, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0036 - val_loss: 0.0058
# Epoch 30/70
# Valid representations :  253 / 299
# Exact representations :  223 / 299
# MSE on test :  0.00567768011670706
# RMSE on test :  0.0753503823262169
#
# Epoch 00030: val_loss improved from 0.00578 to 0.00568, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0032 - val_loss: 0.0057
# Epoch 31/70
# Valid representations :  252 / 299
# Exact representations :  226 / 299
# MSE on test :  0.005587286510744871
# RMSE on test :  0.07474815389522922
#
# Epoch 00031: val_loss improved from 0.00568 to 0.00559, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0033 - val_loss: 0.0056
# Epoch 32/70
# Valid representations :  253 / 299
# Exact representations :  222 / 299
# MSE on test :  0.005647776490039992
# RMSE on test :  0.07515168986815926
#
# Epoch 00032: val_loss did not improve from 0.00559
# 494/494 - 25s - loss: 0.0032 - val_loss: 0.0056
# Epoch 33/70
# Valid representations :  253 / 299
# Exact representations :  227 / 299
# MSE on test :  0.005560528408753213
# RMSE on test :  0.07456895070170434
#
# Epoch 00033: val_loss improved from 0.00559 to 0.00556, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0032 - val_loss: 0.0056
# Epoch 34/70
# Valid representations :  254 / 299
# Exact representations :  225 / 299
# MSE on test :  0.00564272872482851
# RMSE on test :  0.07511809851712509
#
# Epoch 00034: val_loss did not improve from 0.00556
# 494/494 - 25s - loss: 0.0033 - val_loss: 0.0056
# Epoch 35/70
# Valid representations :  253 / 299
# Exact representations :  225 / 299
# MSE on test :  0.005589416993953325
# RMSE on test :  0.07476240361273388
#
# Epoch 00035: val_loss did not improve from 0.00556
# 494/494 - 25s - loss: 0.0031 - val_loss: 0.0056
# Epoch 36/70
# Valid representations :  256 / 299
# Exact representations :  224 / 299
# MSE on test :  0.005442147757084352
# RMSE on test :  0.07377091403178052
#
# Epoch 00036: val_loss improved from 0.00556 to 0.00544, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0029 - val_loss: 0.0054
# Epoch 37/70
# Valid representations :  256 / 299
# Exact representations :  225 / 299
# MSE on test :  0.005596748510064081
# RMSE on test :  0.07481141965010477
#
# Epoch 00037: val_loss did not improve from 0.00544
# 494/494 - 24s - loss: 0.0032 - val_loss: 0.0056
# Epoch 38/70
# Valid representations :  256 / 299
# Exact representations :  221 / 299
# MSE on test :  0.005474060507379262
# RMSE on test :  0.07398689415956898
#
# Epoch 00038: val_loss did not improve from 0.00544
# 494/494 - 25s - loss: 0.0030 - val_loss: 0.0055
# Epoch 39/70
# Valid representations :  255 / 299
# Exact representations :  227 / 299
# MSE on test :  0.005422841330772819
# RMSE on test :  0.07363994385367781
#
# Epoch 00039: val_loss improved from 0.00544 to 0.00542, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0029 - val_loss: 0.0054
# Epoch 40/70
# Valid representations :  255 / 299
# Exact representations :  221 / 299
# MSE on test :  0.005473043340395064
# RMSE on test :  0.0739800198729026
#
# Epoch 00040: val_loss did not improve from 0.00542
# 494/494 - 25s - loss: 0.0030 - val_loss: 0.0055
# Epoch 41/70
# Valid representations :  257 / 299
# Exact representations :  219 / 299
# MSE on test :  0.005350457704080238
# RMSE on test :  0.07314682292540284
#
# Epoch 00041: val_loss improved from 0.00542 to 0.00535, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 25s - loss: 0.0029 - val_loss: 0.0054
# Epoch 42/70
# Valid representations :  255 / 299
# Exact representations :  223 / 299
# MSE on test :  0.005403665696478156
# RMSE on test :  0.07350962995742909
#
# Epoch 00042: val_loss did not improve from 0.00535
# 494/494 - 24s - loss: 0.0028 - val_loss: 0.0054
# Epoch 43/70
# Valid representations :  256 / 299
# Exact representations :  222 / 299
# MSE on test :  0.0053889591094202155
# RMSE on test :  0.07340953009943747
#
# Epoch 00043: val_loss did not improve from 0.00535
# 494/494 - 24s - loss: 0.0029 - val_loss: 0.0054
# Epoch 44/70
# Valid representations :  259 / 299
# Exact representations :  226 / 299
# MSE on test :  0.005307644239538146
# RMSE on test :  0.07285358082852308
#
# Epoch 00044: val_loss improved from 0.00535 to 0.00531, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 24s - loss: 0.0027 - val_loss: 0.0053
# Epoch 45/70
# Valid representations :  253 / 299
# Exact representations :  227 / 299
# MSE on test :  0.005488385560582228
# RMSE on test :  0.07408363895343038
#
# Epoch 00045: val_loss did not improve from 0.00531
# 494/494 - 24s - loss: 0.0030 - val_loss: 0.0055
# Epoch 46/70
# Valid representations :  256 / 299
# Exact representations :  228 / 299
# MSE on test :  0.0052993619376815295
# RMSE on test :  0.07279671653090906
#
# Epoch 00046: val_loss improved from 0.00531 to 0.00530, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 24s - loss: 0.0027 - val_loss: 0.0053
# Epoch 47/70
# Valid representations :  258 / 299
# Exact representations :  229 / 299
# MSE on test :  0.005282634948926878
# RMSE on test :  0.07268173738241869
#
# Epoch 00047: val_loss improved from 0.00530 to 0.00528, saving model to saved_LSTM/best_model0.6544528492769491.hdf5
# 494/494 - 24s - loss: 0.0027 - val_loss: 0.0053
# Epoch 48/70
# Valid representations :  258 / 299
# Exact representations :  224 / 299
# MSE on test :  0.005381839777938887
# RMSE on test :  0.0733610235611451
#
# Epoch 00048: val_loss did not improve from 0.00528
# 494/494 - 24s - loss: 0.0027 - val_loss: 0.0054
# Epoch 49/70
# Valid representations :  255 / 299
# Exact representations :  225 / 299
# MSE on test :  0.00547838411235676
# RMSE on test :  0.07401610711430831
#
# Epoch 00049: val_loss did not improve from 0.00528
# 494/494 - 24s - loss: 0.0027 - val_loss: 0.0055
# Epoch 50/70
# Valid representations :  256 / 299
# Exact representations :  222 / 299
# MSE on test :  0.005444626553721203
# RMSE on test :  0.07378771275572378
#
# Epoch 00050: val_loss did not improve from 0.00528
# 494/494 - 24s - loss: 0.0026 - val_loss: 0.0054
# Epoch 51/70
# Valid representations :  258 / 299
# Exact representations :  224 / 299
# MSE on test :  0.0053527219505468526
# RMSE on test :  0.07316229869643827
#
# Epoch 00051: val_loss did not improve from 0.00528
# 494/494 - 24s - loss: 0.0025 - val_loss: 0.0054
# Epoch 52/70
# Valid representations :  250 / 299
# Exact representations :  222 / 299
# MSE on test :  0.005384988003047607
# RMSE on test :  0.0733824774932518
#
# Epoch 00052: val_loss did not improve from 0.00528
# 494/494 - 24s - loss: 0.0025 - val_loss: 0.0054
# Epoch 00052: early stopping
# End of training !
# CPU Time to train :  6429.839279781001
# Testing on test set ...
# Valid representations :  1913 / 2299
# Exact representations :  1703 / 2299
# MSE on test :  0.005110711090095587
# RMSE on test :  0.07148923758227939
# Testing on training set ...
# Valid representations :  939 / 987
# Exact representations :  932 / 987
# MSE on test :  0.000984158507374293
# RMSE on test :  0.03137130069624613
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#from keras.models import load_model
#model_for_test = load_model("saved_LSTM/best_model_for_test0.012230777794171699.hdf5")
#model = load_model("saved_LSTM/best_model0.012230777794171699.hdf5")
#verbose_training = True
if verbose_training:
        print("Testing on test set ...")
        v, ex, er = test_on_test_set(model, testX_pad[0:300] , testY[0:300], test_sentences[0:300], verbose_training, threshold_factor)
        if minimal_mode:
            print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

        if not(minimal_mode):
            if verbose_training:
                print("Testing on training set ...")
            v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


        #qualitative analysis of the output of the LSTM
        if not(minimal_mode):
            test_sent = ['BEGIN this is a yellow and black rubber hammer. END',
       'BEGIN a yellow bananna END',
       'BEGIN this is a small black flashlight with an attached cloth handle. END',
       'BEGIN the object is a lemon. it is uncut with a sticker still on the skin. END',
       'BEGIN this is a tub of toothpaste with a blue label. END',
       'BEGIN a green marker. END',
       'BEGIN it is a pair of blue and red pliers. END',
       'BEGIN it is a white led lightbulb. END',
       'BEGIN a small white onion. END',
       'BEGIN on the turntable is a metal hammer with a yellow and black plastic handle. END'] #9

            #plot the final outputs on a test sentence
            outputs = test_with_sentences(test_sent , model)
            ind = 9
            plot_final_activation(outputs[ind],
                                concepts_delimitations,
                                output_id_to_concept_dict,
                                nb_concepts,
                                test_sent[ind])

            #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
            s = test_sent[ind]
            suc_outputs = get_successive_outputs(s, model)
            plot_concept_activation(s,
                                    suc_outputs,
                                    concepts_delimitations,
                                    nb_concepts,
                                    savefig = True,
                                    sub_ttl_fig = s + " LSTM")


            #plot the evolution of cell activity
            activations = get_successive_outputs(s, model_for_test)
            plot_hidden_states(s,
                            model_for_test,
                            units_to_plot = 'all',
                            state = 'cell',
                            plt_var = True,
                            plt_sum = False)
# Out:
# Testing on test set ...
# Valid representations :  260 / 300
# Exact representations :  251 / 300
# MSE on test :  0.004866802330331166
# RMSE on test :  0.069762470787173
# Testing on training set ...
# Valid representations :  936 / 990
# Exact representations :  922 / 990
# MSE on test :  0.001671812500601159
# RMSE on test :  0.04088780381239813
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-60c964a17785> in <module>
#      29
#      30             #plot the final outputs on a test sentence
# ---> 31             outputs = test_with_sentences(test_sent , model)
#      32             ind = 9
#      33             plot_final_activation(outputs[ind],
#
# <ipython-input-4-4d47adde8c55> in test_with_sentences(sentences, model)
#       1 def test_with_sentences(sentences, model):
#       2     global max_seq_len
# ----> 3     test = [one_hot_encoding_sentence(s) for s in sentences]
#       4     #test = []
#       5     test_pad = padding(test, max_seq_len)
#
# <ipython-input-4-4d47adde8c55> in <listcomp>(.0)
#       1 def test_with_sentences(sentences, model):
#       2     global max_seq_len
# ----> 3     test = [one_hot_encoding_sentence(s) for s in sentences]
#       4     #test = []
#       5     test_pad = padding(test, max_seq_len)
#
# ~/Downloads/esn-vs-lstm-on-cross-situationnal-learning/data_processing.py in one_hot_encoding_sentence(sentence)
#     207     if sentence == "":
#     208         return None
# --> 209     return np.array(list(map(one_hot_encoding, sentence.split(" "))))
#     210
#     211
#
# ~/Downloads/esn-vs-lstm-on-cross-situationnal-learning/data_processing.py in one_hot_encoding(word)
#     201     global word2one_hot_id
#     202     vect = np.zeros(nb_unique_words)
# --> 203     vect[word2one_hot_id[word]] = 1.
#     204     return vect
#     205
#
# KeyError: 'bananna'

# %%
def output_to_vision(output, nb_concepts, factor,
                     concepts_delimitations, output_id_to_concept_dict):
    objs = []
    nb_objects = 2
    for j in range(nb_objects):
        cat = [None] * 3
        offset = j*nb_concepts
        for i in range(len(concepts_delimitations)):
            cat_activations = output[offset+concepts_delimitations[i][0]:offset+concepts_delimitations[i][1]]
            proba = softmax(cat_activations)
            concept = np.argmax(proba)
            #the threshold to be accepted depend on the number of concept to choose from : must be a factor higher than the uniform proba
            threshold = factor / (concepts_delimitations[i][1] - concepts_delimitations[i][0])
            if proba[concept] < threshold:
                cat[i] = None
            else:
                cat[i] = output_id_to_concept_dict[concepts_delimitations[i][0] + concept]

        objs.append(RecognizedObject(cat[0], cat[1], cat[2])) #object, position, color

    return objs
