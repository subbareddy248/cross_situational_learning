# %%
from sentence_to_predicate import WordPredicate
import json
import sentence_grounding_test_parameters as param
import numpy as np
from recognized_object import RecognizedObject

from plots import *
from data_processing import *

import sys
import time
import matplotlib.pyplot as plt
import math
import os
from sklearn.model_selection import KFold
import pandas as pd
from sklearn.metrics import mean_squared_error
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
from tensorflow import keras

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, Masking, GRU
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from transformers import BertModel, BertTokenizer
from transformers import pipeline
from attention import Attention

# %%
def padding(data_set, max_seq_len = None, special_value = -42):
    if data_set is None:
        return  np.full((1, max_seq_len, nb_unique_words), fill_value=special_value)

    if max_seq_len is None:
        max_seq_len = max([len(s) for s in data_set])

    data_set_pad = np.full((len(data_set), max_seq_len, nb_unique_words), fill_value=special_value)

    for s, x in enumerate(data_set):
        if x is None:
            continue
        seq_len = x.shape[0]
        data_set_pad[s, 0:seq_len, :] = x
    return data_set_pad

# %%
def test_with_sentences(sentences, model):
    global max_seq_len
    #test = [one_hot_encoding_sentence(s) for s in sentences]
    test = []
    
    for s in sentences:
        #print(s)
        temp = []
        for w in s.split():
            temp.append(np.mean(np.array(nlp(w)),axis=1))
        temp = np.array(temp)
        temp = np.reshape(temp,(temp.shape[0]*temp.shape[1], temp.shape[2]))
        test.append(temp)
    #test = []
    test_pad = padding(test, max_seq_len)
    res = model.predict(test_pad)
    return res

# %%
def is_a_valid_imagined_object(predicate, imagined_object):
    """
        Returns whether the predicate description could apply to the imagine_object.

        Inputs:
            predicate: WordPredicate instance
            imagined_object: RecognizedObject instance

    """

    #target = possible_recognized_object_for_predicate(predicate, fill_unkown_fields = False)

    for field in ['category', 'position', 'color']:

        wanted_field = getattr(predicate, field)

        if wanted_field is not None and getattr(imagined_object, field) != wanted_field:
            return False

    return True

def is_a_valid_representation(predicates, imagined_objects):
    """
        Returns whether each predicate  description could apply to its
        corresponding imagined_object.


        Inputs:
            predicates: a list of WordPredicate instances
            imagined_objects: a list of RecognizedObject instance
    """

    return all(map(is_a_valid_imagined_object, predicates, imagined_objects))




def is_an_exact_imagined_object(predicate, imagined_object):
    """
        Returns whether the imagined object matches exactly what the predicate
        describes.

        Inputs:
            predicate: WordPredicate instance
            imagined_object: RecognizedObject instance

    """
    #target = possible_recognized_object_for_predicate(predicate, fill_unkown_fields = False)

    for field in ['category', 'position', 'color']:

        if getattr(imagined_object, field) != getattr(predicate, field):
            return False

    return True

def is_an_exact_representation(predicates, imagined_objects):
    """
        Returns whether the imagined object matches exactly what the predicate
        describes.

        Inputs:
            predicates: a list of WordPredicate instances
            imagined_objects: a list of RecognizedObject instance
    """

    return all(map(is_an_exact_imagined_object, predicates, imagined_objects))

# %%
def generate_labels_valid(sentences):
    words = sentences.replace(".", "").split()
    obj = []
    col = []
    pos = []
    for w in words:
        #print(w)
        if '<'+w+'_obj>' in concepts:
            obj.append('<'+w+'_obj>')
        if '<'+w+'_col>' in concepts:
            col.append('<'+w+'_col>')
        if '<'+w+'_pos>' in concepts:
            pos.append('<'+w+'_pos>')
    ss = ''
    if len(obj)>0:
        if len(pos)>0:
            if len(col)>0:
                return RecognizedObject(obj[0],pos[0],col[0])
            else:
                return RecognizedObject(obj[0],pos[0],None)
        else:
            if len(col)>0:
                return RecognizedObject(obj[0],None,col[0])
            else:
                return RecognizedObject(obj[0],None,None)
    else:
        if len(pos)>0:
            if len(col)>0:
                return RecognizedObject(None,pos[0],col[0])
            else:
                return RecognizedObject(None,pos[0],None)
        else:
            if len(col)>0:
                return RecognizedObject(None,None,col[0])
            else:
                return RecognizedObject(None,None,None)

# %%
def test_on_test_set(model, testX, testY, test_sentences, verbose, threshold_factor):
    test_outputs = model.predict(testX)
    #print(test_outputs[0].shape)
    test_res = model.test_on_batch(testX, testY)
    exact = 0
    valid = 0
    for i in np.arange(len(test_outputs)):
        v = output_to_vision(test_outputs[i],nb_concepts,
                             threshold_factor, concepts_delimitations, output_id_to_concept_dict)
        #pred = sentence_to_pred(sentences[i], sent_to_role)
        pred = []
        clauses = test_sentences[i].split(" and ")
        if len(clauses) == 1:
            if len(test_sentences[i].split("."))>2:
                #print(s.split("."))
                pred.append(generate_labels_valid(test_sentences[i].split(".")[0]))
                pred.append(generate_labels_valid(test_sentences[i].split(".")[1]))
            else:
                pred.append(generate_labels_valid(test_sentences[i]))
                pred.append(RecognizedObject(None,None,None))
        else:
            for j in range(len(clauses)):
                pred.append(generate_labels_valid(clauses[j]))
        #print(v, pred)       
        if is_an_exact_representation(pred, v):
            exact +=1

        if is_a_valid_representation(pred, v):
            valid +=1

        if is_a_valid_representation(pred, v) and not(is_an_exact_representation(pred, v)):
            #print(pred, v, test_outputs[i])
            #print(i)
            pass

    nb_sample = testX.shape[0]
    test_res = mean_squared_error(test_outputs,testY)
    if verbose:
        print("Valid representations : ", valid, "/", nb_sample)
        print("Exact representations : ", exact, "/", nb_sample)
        print("MSE on test : ", test_res)
        print("RMSE on test : ", np.sqrt(test_res))


    return 1-valid/nb_sample, 1-exact/nb_sample, test_res

# %%
## to get the evolution of the loss during training
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        self.exact_errors = []
        self.valid_errors = []

    def on_epoch_end(self, epoch, logs=None):
        global validationX_pad
        global validationY
        self.losses.append(logs.get('loss'))

        v, ex, er = test_on_test_set(self.model, validationX_pad, validationY, validation_sentences, True, 1.3)

        self.val_losses.append(er)
        self.exact_errors.append(ex)
        self.valid_errors.append(v)

    def plot_loss(self):
        plt.figure()
        plt.plot(self.losses, color = "black", label = "loss")
        plt.plot(self.val_losses, color = "red", label = "loss on validation set")
        plt.xlabel("epochs of training")
        plt.title("MSE during training")
        plt.legend()
        plt.show()
        plt.figure()
        plt.title("Performance on validation set during training")
        plt.plot(self.exact_errors, color = "blue", label = "exact error")
        plt.plot(self.valid_errors, color = "green", label = "valid error")
        plt.legend()
        plt.show()

# %%
def get_successive_outputs(sentence, model):
    words = sentence.split(" ")
    prefixes = []
    for i in range(len(words)+1):
        prefixes.append(" ".join(words[:i]))
    print(prefixes)
    vect = test_with_sentences(prefixes[1:], model)
    return vect

# %%
def get_inner_states(sentences, model, only_last = False, info_obj_nb = False):
    all_states = [[] for i in range(len(model.outputs))]

    clause_nbs =[]

    for k in range(len(sentences)):
        states = get_successive_outputs(sentences[k], model)

        if info_obj_nb:
            words = sentences[k].split(" ")
            clause_id = 0
            clause_nbs.append(clause_id)
            for w in words:
                if w == 'and':
                    clause_id +=1
                clause_nbs.append(clause_id)
                if w == 'and':
                    clause_id +=1
            clause_nbs[-1] = 3 #we also mark the final states

        if not(only_last):
            for j in range(len(states)):
                all_states[j].append(states[j])
        else:
            for j in range(len(states)):
                all_states[j].append(states[j][-1] )

    if not(only_last):
        for i in range(len(all_states)):
            all_states[i] = np.concatenate(all_states[i])
    else:
        for i in range(len(all_states)):
            all_states[i] = np.array(all_states[i])

    if info_obj_nb:
        return all_states, np.array(clause_nbs)
    else:
        return all_states

# %%
def plot_hidden_states(sentence, model_for_test, state = 'cell', units_to_plot = 'all', plt_var = False, plt_sum = False):
    activations = get_successive_outputs(sentence, model_for_test)

    plot_hidden_state_activation(sentence,
                                 activations,
                                 state,
                                 units_to_plot,
                                 plot_variation = plt_var,
                                 plot_sum = plt_sum)

# %%
dataset = pd.read_csv('./text.tsv', sep='\t')
dataset.dropna()
dataset.head()
# Out:
#                            hit_id                         worker_id  \
# 0  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 1  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 2  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 3  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
# 4  306996CF6WIITTJBR6Q44WPDCQ11BX  1717708c7af5468188e808a8d09b5c98
#
#    worktime_s             item_id  \
# 0         380          potato_3_2
# 1         380      can_opener_4_3
# 2         380  measuring_tape_3_3
# 3         380            fork_3_1
# 4         380      can_opener_3_4
#
#                                                 text
# 0  A single small red skinned potato is laying on...
# 1  The manual can opener has a black plastic hand...
# 2  A pink and black measuring tape is laying on i...
# 3  A silver metal fork is laying with its tines p...
# 4  A manual can opener with a light blue plastic ...

# %%
concepts = []
sentences = []
for i in np.arange(dataset.shape[0]):
    try:
        #print(i.split('_'))
        if len(dataset['item_id'][i].split('_')) == 3:
            concepts.append(dataset['item_id'][i].split('_')[0])
            sentences.append(dataset['text'][i])
        else:
            concepts.append(dataset['item_id'][i].split('_')[0]+" "+dataset['item_id'][i].split('_')[1])
            sentences.append(dataset['text'][i])
        #else:
        #    concepts.append(dataset['item_id'][i].split('_')[0]+dataset['item_id'][i].split('_')[1])
        #    sentences.append(dataset['text'][i].replace(dataset['item_id'][i].split('_')[0]+" "+dataset['item_id'][i].split('_')[1],dataset['item_id'][i].split('_')[0]+dataset['item_id'][i].split('_')[1]))
    except:
        continue

# %%
final_sentences = []
final_concepts = []
for s in sentences:
    try:
        if s.split(" "):
            final_sentences.append(s.lower())
    except:
        print(s)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
object_names = np.random.choice(np.unique(concepts),20, replace = False)

# %%
#object_names = np.unique(concepts)
color_names = ['red', 'black', 'blue', 'green', 'white', 'pink', 'orange', 'yellow']
position_names = ['left', 'right', 'middle', 'top', 'bottom', 'front', 'back']

# %%
final = []
for i in final_sentences:
    for j in object_names:
        if j in i:
            final.append(i)

# %%
def add_object(name, concept = None, build_after = True):
    
    if concept is None:
        concept = '<' + name.lower() + '_obj>'
    
    if name not in OBJECT_NAMES:
        OBJECT_NAMES.append(name)
        
    if concept not in CATEGORIES:
        CATEGORIES.append(concept)
        
    OBJ_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()
    
    
def add_position(name, concept = None, build_after=True):
    
    if concept is None:
        concept = '<' + name.lower() + '_pos>'
    
    if name not in POSITION_NAMES:
        POSITION_NAMES.append(name)
    
    if concept not in POSITIONS:
        POSITIONS.append(concept)
        
    POSITION_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()
       
        
def add_color(name, concept = None, build_after=True):
    
    if concept is None:
        concept = '<' + name.lower() + '_col>'
    
    
    if name not in COLOR_NAMES:
        COLOR_NAMES.append(name)
    
    if concept not in COLORS:
        COLORS.append(concept)
        
    COLOR_NAME_TO_CONCEPT[name] = concept
    
    if build_after:
        build_all()

# %%
# Words
OBJECT_NAMES = []
COLOR_NAMES = []
POSITION_NAMES = []

# Concepts
CATEGORIES = []
POSITIONS = []
COLORS = []

OBJ_NAME_TO_CONCEPT = dict()
COLOR_NAME_TO_CONCEPT = dict()
POSITION_NAME_TO_CONCEPT = dict()

# %%
for obj in object_names:
    add_object(obj, build_after = False)
        
for col in color_names:
    add_color(col, build_after = False)
        
for pos in position_names:
    add_position(pos, build_after = False)

# %%
################### MAIN #####################

## Parameters

add_begin_end = True #add the word "BEGIN" at the beggining and "END" at the end of all sentences ?
#nb_objects = np.unique(concepts).shape[0] #number of object in the vocabulary used to generate the sentences (the bigger the harder)
nb_objects = 20

special_value = -42 #special value for masking
batch_size = 2
nb_epoch = 70
lstm_units = 20
dropout = 0.2
test_version = True #if we just create a model to do the task (named "model" in the code)
                    #or in addition, create a model to do extensive test to get access to
                    #cell states of the LSTM (named "model_for_test" in the code)

use_save_version = False #use model saved from a previous run
if use_save_version:
    path = r"saved_LSTM/" #path to the model .hdf5 file(s)
    model_id = '0.9144544314163248' #model id (a random float to identify the file(s) of the model save)

threshold_factor = 1.3 # the factor used to get the threshold in the creation of he discrete representation


minimal_mode = False #if minimal mode is on, the model will only be trained and tested on test set. The only text print will be "nb of objects, valid error on test set, exact error on test set, RMSE on test set, time to train"

verbose_training = True

# %%
other_words = []
if add_begin_end:
    other_words.append("BEGIN")
    other_words.append("END")

#init_one_hot_encoding(list(sent_to_role.keys()) + other_words)
#nb_unique_words = len(word2one_hot_id)

# %%
#concept dictionnary initialisation (it's the link between the output position and their meaning)
concepts = CATEGORIES + POSITIONS + COLORS

nb_concepts = len(concepts)

output_size = 2*nb_concepts

concept_to_output_id_dict = {}
output_id_to_concept_dict = {}
for i,c in enumerate(concepts):
    concept_to_output_id_dict[c] = i
    output_id_to_concept_dict[i] = c

# %%
concepts_delimitations = [(0,len(CATEGORIES)),
                          (len(CATEGORIES),
                          len(CATEGORIES) + len(POSITIONS)),
                          (len(CATEGORIES) + len(POSITIONS),
                          len(CATEGORIES) + len(POSITIONS)+ len(COLORS))]

# %%
len(final)
# Out:
# 2305

# %%
##generate data
#we adjust the different dictionnaries to include sentences with BEGIN and END
final_sentences = final
if add_begin_end:
    for i in range(len(final_sentences)):
        final_sentences[i] = "BEGIN "+ final_sentences[i]+ " END"

# %%
#create the training, test and validation set

np.random.shuffle(final_sentences)

train_data = 1000

test_data = 1305

# %%
init_one_hot_encoding(final_sentences + other_words)
nb_unique_words = len(word2one_hot_id)

# %%
train_sentences = (final_sentences[:train_data])


test_sentences = (final_sentences[-test_data:])

# %%
def generate_labels(sen_num, index_num, s):
    words = s.replace(".", "").split()
    for w in words:
        if '<'+w+'_obj>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_obj>')]=1
        if '<'+w+'_col>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_col>')]=1
        if '<'+w+'_pos>' in concepts:
            trainY[sen_num][index_num+concepts.index('<'+w+'_pos>')]=1

# %%
trainY = np.zeros([len(train_sentences),output_size])
print(trainY.shape)
i = 0
more_objects = []
for s in train_sentences:
    try:
        clauses = s.split(" and ")
        if len(clauses) == 1:
            if len(s.split("."))>2:
                #print(s.split("."))
                generate_labels(i, 0, s.split(".")[0])
                generate_labels(i, len(concepts), s.split(".")[1])
            else:
                generate_labels(i, 0, s)
        else:
            for j in range(len(clauses)):
                generate_labels(i, j*len(concepts), clauses[j])
    except:
        more_objects.append(i)
    i+=1
# Out:
# (1000, 70)

# %%
trainY = np.array(trainY)
trainY = np.delete(trainY,more_objects, axis=0)
print(trainY.shape)

train_sentences = np.array(train_sentences)
train_sentences = np.delete(train_sentences,more_objects, axis=0)
print(train_sentences.shape)
# Out:
# (991, 70)
# (991,)

# %%
def generate_labels_test(sen_num, index_num, s):
    words = s.replace(".", "").split()
    for w in words:
        if '<'+w+'_obj>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_obj>')]=1
        if '<'+w+'_col>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_col>')]=1
        if '<'+w+'_pos>' in concepts:
            testY[sen_num][index_num+concepts.index('<'+w+'_pos>')]=1

# %%
testY = np.zeros([len(test_sentences),output_size])
#print(target_output.shape)
i = 0
more_objects_test = []
for s in test_sentences:
    try:
        clauses = s.split(" and ")
        if len(clauses) == 1:
            if len(s.split("."))>2:
                #print(s.split("."))
                generate_labels_test(i, 0, s.split(".")[0])
                generate_labels_test(i, len(concepts), s.split(".")[1])
            else:
                generate_labels_test(i, 0, s)
        else:
            for j in range(len(clauses)):
                generate_labels_test(i, j*len(concepts), clauses[j])
    except:
        more_objects_test.append(i)
    i+=1

# %%
testY = np.array(testY)
testY = np.delete(testY,more_objects_test, axis=0)
print(testY.shape)

test_sentences = np.array(test_sentences)
test_sentences = np.delete(test_sentences,more_objects_test, axis=0)
print(test_sentences.shape)
# Out:
# (1286, 70)
# (1286,)

# %%
do_lower_case = True
model = BertModel.from_pretrained("anonymous/BERT-NLP", output_attentions=True)
tokenizer = BertTokenizer.from_pretrained("anonymous/BERT-NLP", do_lower_case=do_lower_case)

nlp = pipeline('feature-extraction',model=model, tokenizer=tokenizer)

# %% [raw]
# trainX = [one_hot_encoding_sentence(s) for s in train_sentences]
# #trainY = np.array([sentence_to_output_teacher_vector(s,
# #                                                     concept_to_output_id_dict,
# #                                                     nb_concepts) for s in train_sentences])
#
#
# testX = [one_hot_encoding_sentence(s) for s in test_sentences]
# #testY = np.array([sentence_to_output_teacher_vector(s,
# #                                                    sent_to_role,
# #                                                    concept_to_output_id_dict,
# #                                                    nb_concepts) for s in test_sentences])

# %%
trainX = []
for s in train_sentences:
    temp = []
    for w in s.split():
        temp.append(np.mean(np.array(nlp(w)),axis=1))
    temp = np.array(temp)
    temp = np.reshape(temp,(temp.shape[0]*temp.shape[1], temp.shape[2]))
    #temp = np.mean(temp, axis=1)
    #print(np.mean(temp, axis=1).shape)
    #print(temp.shape)
    trainX.append(temp)

# %%
testX = []
for s in test_sentences:
    temp = []
    for w in s.split():
        temp.append(np.mean(np.array(nlp(w)),axis=1))
    temp = np.array(temp)
    temp = np.reshape(temp,(temp.shape[0]*temp.shape[1], temp.shape[2]))
    #temp = np.mean(temp, axis=1)
    #print(np.mean(temp, axis=1).shape)
    #print(temp.shape)
    testX.append(temp)

# %%
#create the training, test and validation set
validationX = testX[1100:]
validationY = testY[1100:]
validation_sentences = test_sentences[1100:]

# %%
nb_unique_words=768
max_seq_len = max([len(s.split(" ")) for s in final_sentences])

trainX_pad = padding(trainX,max_seq_len = max_seq_len)
testX_pad = padding(testX, max_seq_len = max_seq_len)
validationX_pad = padding(validationX, max_seq_len = max_seq_len)

# %%
print(trainX_pad.shape, testX_pad.shape, validationX_pad.shape)
# Out:
# (991, 54, 768) (1286, 54, 768) (186, 54, 768)

# %%
CONCEPT_LISTS = [
            CATEGORIES,
            POSITIONS,
            COLORS
            ]
def plot_concept_activation(sentence, activations, concepts_delim,nb_concepts, output_function = None, savefig=False, sub_ttl_fig='', ylims=(-0.4, 1.4)):
    """
        Plots activation through time of the different concepts while hearing
        the sentence. If output_function is not None, it is applied to the reservoir
        output vector before plotting.
        This is a reuse of a function developped by Alexis Juven.
    """

    outputs = activations.copy()
    activation_threshold = 0.5

    if output_function is not None:

        activation_threshold = output_function(activation_threshold)

        for i in range(outputs.shape[0]):
            outputs[i, :] = output_function(outputs[i, :])


    words = sentence.split(" ")
    max_nb_seen_objects = 2
    nb_object_properties = 3

    fig, axes = plt.subplots(nb_object_properties, max_nb_seen_objects, figsize=(25,20))


    concept_delimitations = [t[0] for t in concepts_delim] + [concepts_delim[-1][1]]

    for i in range(max_nb_seen_objects):

        offset = i * nb_concepts

        axes[0, i].set_title("Object " + str(i+1), fontsize = 22)

        for j in range(nb_object_properties):

            ax = axes[j, i]
            ax.plot(outputs[:, offset + concept_delimitations[j] : offset + concept_delimitations[j+1]], linewidth = 4)
            ax.legend(CONCEPT_LISTS[j], loc = 2, fontsize = 22)

            ax.set_yticks([0., 0.5, 1.])
            ax.set_yticklabels([0., 0.5, 1.], fontsize = 20)

            ax.set_ylim([ylims[0], ylims[1]])

            ax.set_xticks(np.arange(len(words)))
            ax.set_xticklabels(words, fontsize = 24)
            # Rotate the tick labels and set their alignment.
            plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor", fontsize = 22)

            ax.plot(len(words) * [activation_threshold], '--', color = 'grey', linewidth = 3)

    fig.suptitle(sentence, fontsize = 26)
    plt.subplots_adjust(hspace = 0.3)

    if savefig:
        plt.savefig('sentence_'+sub_ttl_fig+".png", bbox_inches='tight')
        plt.close()
    else:
        fig.show()
        #plt.show()

# %%
lstm_units = 20
for _ in np.arange(1):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, return_sequences=True, dropout = dropout)(masked)
                    attention_weights, attention_output = Attention(20)(lstm_out)
                    output_to_train = Dense(output_size)(attention_output)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[0:1100] , testY[0:1100], test_sentences[0:1100], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_29"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_14 (Masking)            (None, 54, 768)      0           input_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  [(None, 54, 20), (No 63120       masking_14[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 20)           0           lstm_14[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 20)       400         lstm_14[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 20)           0           lstm_14[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 40)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 20)           800         attention_output[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 70)           1470        attention_vector[0][0]
# ==================================================================================================
# Total params: 65,790
# Trainable params: 65,790
# Non-trainable params: 0
# __________________________________________________________________________________________________
# model for hidden states:  None
# Model: "model_28"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_14 (Masking)            (None, 54, 768)      0           input_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  [(None, 54, 20), (No 63120       masking_14[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 20)           0           lstm_14[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 20)       400         lstm_14[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 20)           0           lstm_14[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 40)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 20)           800         attention_output[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 70)           1470        attention_vector[0][0]
# ==================================================================================================
# Total params: 65,790
# Trainable params: 65,790
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  36 / 186
# Exact representations :  35 / 186
# MSE on test :  0.01790578699199332
# RMSE on test :  0.13381250685938637
#
# Epoch 00001: val_loss improved from inf to 0.01791, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 8s - loss: 0.0214 - val_loss: 0.0179
# Epoch 2/70
# Valid representations :  84 / 186
# Exact representations :  73 / 186
# MSE on test :  0.013813169524443034
# RMSE on test :  0.11752944109644628
#
# Epoch 00002: val_loss improved from 0.01791 to 0.01381, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0171 - val_loss: 0.0138
# Epoch 3/70
# Valid representations :  115 / 186
# Exact representations :  104 / 186
# MSE on test :  0.011581414482918889
# RMSE on test :  0.10761698045809913
#
# Epoch 00003: val_loss improved from 0.01381 to 0.01158, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0139 - val_loss: 0.0116
# Epoch 4/70
# Valid representations :  119 / 186
# Exact representations :  106 / 186
# MSE on test :  0.010533072845862853
# RMSE on test :  0.10263075974513125
#
# Epoch 00004: val_loss improved from 0.01158 to 0.01053, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0123 - val_loss: 0.0105
# Epoch 5/70
# Valid representations :  128 / 186
# Exact representations :  115 / 186
# MSE on test :  0.009848608508182082
# RMSE on test :  0.09924015572429379
#
# Epoch 00005: val_loss improved from 0.01053 to 0.00985, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0113 - val_loss: 0.0098
# Epoch 6/70
# Valid representations :  134 / 186
# Exact representations :  122 / 186
# MSE on test :  0.009283954584849841
# RMSE on test :  0.09635328009388078
#
# Epoch 00006: val_loss improved from 0.00985 to 0.00928, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0106 - val_loss: 0.0093
# Epoch 7/70
# Valid representations :  134 / 186
# Exact representations :  123 / 186
# MSE on test :  0.008784043401861456
# RMSE on test :  0.09372322765388234
#
# Epoch 00007: val_loss improved from 0.00928 to 0.00878, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0101 - val_loss: 0.0088
# Epoch 8/70
# Valid representations :  134 / 186
# Exact representations :  126 / 186
# MSE on test :  0.008455922932068902
# RMSE on test :  0.09195609241409132
#
# Epoch 00008: val_loss improved from 0.00878 to 0.00846, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0098 - val_loss: 0.0085
# Epoch 9/70
# Valid representations :  140 / 186
# Exact representations :  127 / 186
# MSE on test :  0.008058700085732534
# RMSE on test :  0.0897702628142111
#
# Epoch 00009: val_loss improved from 0.00846 to 0.00806, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0093 - val_loss: 0.0081
# Epoch 10/70
# Valid representations :  143 / 186
# Exact representations :  136 / 186
# MSE on test :  0.007642757687230249
# RMSE on test :  0.08742286707281025
#
# Epoch 00010: val_loss improved from 0.00806 to 0.00764, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0091 - val_loss: 0.0076
# Epoch 11/70
# Valid representations :  146 / 186
# Exact representations :  137 / 186
# MSE on test :  0.007404465538654137
# RMSE on test :  0.08604920417211386
#
# Epoch 00011: val_loss improved from 0.00764 to 0.00740, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0086 - val_loss: 0.0074
# Epoch 12/70
# Valid representations :  147 / 186
# Exact representations :  139 / 186
# MSE on test :  0.007168938150461737
# RMSE on test :  0.08466958220318403
#
# Epoch 00012: val_loss improved from 0.00740 to 0.00717, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0083 - val_loss: 0.0072
# Epoch 13/70
# Valid representations :  149 / 186
# Exact representations :  140 / 186
# MSE on test :  0.006964071189376284
# RMSE on test :  0.08345101071512726
#
# Epoch 00013: val_loss improved from 0.00717 to 0.00696, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0079 - val_loss: 0.0070
# Epoch 14/70
# Valid representations :  150 / 186
# Exact representations :  140 / 186
# MSE on test :  0.006889572835940055
# RMSE on test :  0.08300345074718313
#
# Epoch 00014: val_loss improved from 0.00696 to 0.00689, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0077 - val_loss: 0.0069
# Epoch 15/70
# Valid representations :  150 / 186
# Exact representations :  142 / 186
# MSE on test :  0.006751456473339544
# RMSE on test :  0.08216724696215362
#
# Epoch 00015: val_loss improved from 0.00689 to 0.00675, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0075 - val_loss: 0.0068
# Epoch 16/70
# Valid representations :  150 / 186
# Exact representations :  137 / 186
# MSE on test :  0.006758430661356105
# RMSE on test :  0.0822096749863184
#
# Epoch 00016: val_loss did not improve from 0.00675
# 496/496 - 7s - loss: 0.0073 - val_loss: 0.0068
# Epoch 17/70
# Valid representations :  151 / 186
# Exact representations :  139 / 186
# MSE on test :  0.006667049447786243
# RMSE on test :  0.08165200210519179
#
# Epoch 00017: val_loss improved from 0.00675 to 0.00667, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0071 - val_loss: 0.0067
# Epoch 18/70
# Valid representations :  150 / 186
# Exact representations :  139 / 186
# MSE on test :  0.006399462944279171
# RMSE on test :  0.07999664333132467
#
# Epoch 00018: val_loss improved from 0.00667 to 0.00640, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0070 - val_loss: 0.0064
# Epoch 19/70
# Valid representations :  151 / 186
# Exact representations :  140 / 186
# MSE on test :  0.00646346265848914
# RMSE on test :  0.0803956631820967
#
# Epoch 00019: val_loss did not improve from 0.00640
# 496/496 - 7s - loss: 0.0068 - val_loss: 0.0065
# Epoch 20/70
# Valid representations :  151 / 186
# Exact representations :  140 / 186
# MSE on test :  0.006447640915267494
# RMSE on test :  0.08029720365783291
#
# Epoch 00020: val_loss did not improve from 0.00640
# 496/496 - 7s - loss: 0.0068 - val_loss: 0.0064
# Epoch 21/70
# Valid representations :  151 / 186
# Exact representations :  138 / 186
# MSE on test :  0.006642937087354801
# RMSE on test :  0.08150421515084236
#
# Epoch 00021: val_loss did not improve from 0.00640
# 496/496 - 7s - loss: 0.0066 - val_loss: 0.0066
# Epoch 22/70
# Valid representations :  151 / 186
# Exact representations :  140 / 186
# MSE on test :  0.006413664982834963
# RMSE on test :  0.08008536060251563
#
# Epoch 00022: val_loss did not improve from 0.00640
# 496/496 - 7s - loss: 0.0064 - val_loss: 0.0064
# Epoch 23/70
# Valid representations :  152 / 186
# Exact representations :  141 / 186
# MSE on test :  0.006074371970640283
# RMSE on test :  0.07793825742624916
#
# Epoch 00023: val_loss improved from 0.00640 to 0.00607, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0063 - val_loss: 0.0061
# Epoch 24/70
# Valid representations :  151 / 186
# Exact representations :  137 / 186
# MSE on test :  0.006189282120643898
# RMSE on test :  0.0786719906996378
#
# Epoch 00024: val_loss did not improve from 0.00607
# 496/496 - 7s - loss: 0.0063 - val_loss: 0.0062
# Epoch 25/70
# Valid representations :  152 / 186
# Exact representations :  140 / 186
# MSE on test :  0.005939975279875981
# RMSE on test :  0.07707123510023685
#
# Epoch 00025: val_loss improved from 0.00607 to 0.00594, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0061 - val_loss: 0.0059
# Epoch 26/70
# Valid representations :  152 / 186
# Exact representations :  143 / 186
# MSE on test :  0.0057688388378483646
# RMSE on test :  0.07595287247924443
#
# Epoch 00026: val_loss improved from 0.00594 to 0.00577, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0061 - val_loss: 0.0058
# Epoch 27/70
# Valid representations :  152 / 186
# Exact representations :  143 / 186
# MSE on test :  0.006198467756986289
# RMSE on test :  0.07873034838603402
#
# Epoch 00027: val_loss did not improve from 0.00577
# 496/496 - 7s - loss: 0.0059 - val_loss: 0.0062
# Epoch 28/70
# Valid representations :  153 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005451719010074791
# RMSE on test :  0.07383575698856748
#
# Epoch 00028: val_loss improved from 0.00577 to 0.00545, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0060 - val_loss: 0.0055
# Epoch 29/70
# Valid representations :  153 / 186
# Exact representations :  144 / 186
# MSE on test :  0.00545475349014105
# RMSE on test :  0.0738563029818109
#
# Epoch 00029: val_loss did not improve from 0.00545
# 496/496 - 7s - loss: 0.0058 - val_loss: 0.0055
# Epoch 30/70
# Valid representations :  152 / 186
# Exact representations :  144 / 186
# MSE on test :  0.0054405442501637025
# RMSE on test :  0.07376004507972933
#
# Epoch 00030: val_loss improved from 0.00545 to 0.00544, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0058 - val_loss: 0.0054
# Epoch 31/70
# Valid representations :  153 / 186
# Exact representations :  143 / 186
# MSE on test :  0.005376778484564429
# RMSE on test :  0.07332651965397259
#
# Epoch 00031: val_loss improved from 0.00544 to 0.00538, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0058 - val_loss: 0.0054
# Epoch 32/70
# Valid representations :  152 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005421321994910223
# RMSE on test :  0.07362962715449688
#
# Epoch 00032: val_loss did not improve from 0.00538
# 496/496 - 7s - loss: 0.0057 - val_loss: 0.0054
# Epoch 33/70
# Valid representations :  155 / 186
# Exact representations :  147 / 186
# MSE on test :  0.005627366774132487
# RMSE on test :  0.07501577683482646
#
# Epoch 00033: val_loss did not improve from 0.00538
# 496/496 - 7s - loss: 0.0057 - val_loss: 0.0056
# Epoch 34/70
# Valid representations :  151 / 186
# Exact representations :  139 / 186
# MSE on test :  0.0060803737034909495
# RMSE on test :  0.07797675104472454
#
# Epoch 00034: val_loss did not improve from 0.00538
# 496/496 - 7s - loss: 0.0056 - val_loss: 0.0061
# Epoch 35/70
# Valid representations :  154 / 186
# Exact representations :  145 / 186
# MSE on test :  0.005342272312169895
# RMSE on test :  0.07309084971574688
#
# Epoch 00035: val_loss improved from 0.00538 to 0.00534, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0056 - val_loss: 0.0053
# Epoch 36/70
# Valid representations :  153 / 186
# Exact representations :  145 / 186
# MSE on test :  0.005299645590086889
# RMSE on test :  0.07279866475483522
#
# Epoch 00036: val_loss improved from 0.00534 to 0.00530, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0055 - val_loss: 0.0053
# Epoch 37/70
# Valid representations :  152 / 186
# Exact representations :  142 / 186
# MSE on test :  0.0052386905684062715
# RMSE on test :  0.07237879916388687
#
# Epoch 00037: val_loss improved from 0.00530 to 0.00524, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0053 - val_loss: 0.0052
# Epoch 38/70
# Valid representations :  155 / 186
# Exact representations :  146 / 186
# MSE on test :  0.00531678215203822
# RMSE on test :  0.07291626808907749
#
# Epoch 00038: val_loss did not improve from 0.00524
# 496/496 - 7s - loss: 0.0055 - val_loss: 0.0053
# Epoch 39/70
# Valid representations :  153 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005210999031464222
# RMSE on test :  0.07218724978459992
#
# Epoch 00039: val_loss improved from 0.00524 to 0.00521, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0054 - val_loss: 0.0052
# Epoch 40/70
# Valid representations :  155 / 186
# Exact representations :  147 / 186
# MSE on test :  0.005218365037117685
# RMSE on test :  0.07223825189688414
#
# Epoch 00040: val_loss did not improve from 0.00521
# 496/496 - 7s - loss: 0.0054 - val_loss: 0.0052
# Epoch 41/70
# Valid representations :  153 / 186
# Exact representations :  146 / 186
# MSE on test :  0.005261542145016775
# RMSE on test :  0.07253648836976308
#
# Epoch 00041: val_loss did not improve from 0.00521
# 496/496 - 7s - loss: 0.0053 - val_loss: 0.0053
# Epoch 42/70
# Valid representations :  155 / 186
# Exact representations :  146 / 186
# MSE on test :  0.005078274447075355
# RMSE on test :  0.07126201265102856
#
# Epoch 00042: val_loss improved from 0.00521 to 0.00508, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0053 - val_loss: 0.0051
# Epoch 43/70
# Valid representations :  153 / 186
# Exact representations :  146 / 186
# MSE on test :  0.0053512814545401315
# RMSE on test :  0.07315245351005072
#
# Epoch 00043: val_loss did not improve from 0.00508
# 496/496 - 7s - loss: 0.0053 - val_loss: 0.0054
# Epoch 44/70
# Valid representations :  154 / 186
# Exact representations :  147 / 186
# MSE on test :  0.004962377869825364
# RMSE on test :  0.07044414716515038
#
# Epoch 00044: val_loss improved from 0.00508 to 0.00496, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0052 - val_loss: 0.0050
# Epoch 45/70
# Valid representations :  154 / 186
# Exact representations :  147 / 186
# MSE on test :  0.005079342217470819
# RMSE on test :  0.07126950411972023
#
# Epoch 00045: val_loss did not improve from 0.00496
# 496/496 - 7s - loss: 0.0052 - val_loss: 0.0051
# Epoch 46/70
# Valid representations :  154 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005126568696366008
# RMSE on test :  0.07160006072878715
#
# Epoch 00046: val_loss did not improve from 0.00496
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0051
# Epoch 47/70
# Valid representations :  154 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005391578034607584
# RMSE on test :  0.07342736570657825
#
# Epoch 00047: val_loss did not improve from 0.00496
# 496/496 - 7s - loss: 0.0052 - val_loss: 0.0054
# Epoch 48/70
# Valid representations :  155 / 186
# Exact representations :  145 / 186
# MSE on test :  0.004937622362246404
# RMSE on test :  0.07026821729805306
#
# Epoch 00048: val_loss improved from 0.00496 to 0.00494, saving model to saved_LSTM/best_model0.6803649892769342.hdf5
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0049
# Epoch 49/70
# Valid representations :  155 / 186
# Exact representations :  147 / 186
# MSE on test :  0.004944161811688758
# RMSE on test :  0.07031473395874266
#
# Epoch 00049: val_loss did not improve from 0.00494
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0049
# Epoch 50/70
# Valid representations :  154 / 186
# Exact representations :  142 / 186
# MSE on test :  0.005531121860896432
# RMSE on test :  0.074371512428459
#
# Epoch 00050: val_loss did not improve from 0.00494
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0055
# Epoch 51/70
# Valid representations :  154 / 186
# Exact representations :  144 / 186
# MSE on test :  0.005530205955591044
# RMSE on test :  0.07436535453819233
#
# Epoch 00051: val_loss did not improve from 0.00494
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0055
# Epoch 52/70
# Valid representations :  154 / 186
# Exact representations :  142 / 186
# MSE on test :  0.0051950237178774354
# RMSE on test :  0.07207651294199405
#
# Epoch 00052: val_loss did not improve from 0.00494
# 496/496 - 7s - loss: 0.0052 - val_loss: 0.0052
# Epoch 53/70
# Valid representations :  154 / 186
# Exact representations :  145 / 186
# MSE on test :  0.004938862830514953
# RMSE on test :  0.07027704341045483
#
# Epoch 00053: val_loss did not improve from 0.00494
# 496/496 - 7s - loss: 0.0049 - val_loss: 0.0049
# Epoch 00053: early stopping
# End of training !
# CPU Time to train :  1022.4304094190011
# Testing on test set ...
# Valid representations :  844 / 1100
# Exact representations :  794 / 1100
# MSE on test :  0.005917233933958972
# RMSE on test :  0.076923559030761
# Testing on training set ...
# Valid representations :  782 / 991
# Exact representations :  746 / 991
# MSE on test :  0.00456727427137994
# RMSE on test :  0.06758161193238839
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
lstm_units = 40
for _ in np.arange(5):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, return_sequences=True, dropout = dropout)(masked)
                    attention_weights, attention_output = Attention(40)(lstm_out)
                    output_to_train = Dense(output_size)(attention_output)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[0:1100] , testY[0:1100], test_sentences[0:1100], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_12 (Masking)            (None, 54, 768)      0           input_13[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  [(None, 54, 40), (No 129440      masking_12[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 40)           0           lstm_12[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 40)       1600        lstm_12[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 40)           0           lstm_12[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 80)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 40)           3200        attention_output[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 70)           2870        attention_vector[0][0]
# ==================================================================================================
# Total params: 137,110
# Trainable params: 137,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# model for hidden states:  None
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_12 (Masking)            (None, 54, 768)      0           input_13[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  [(None, 54, 40), (No 129440      masking_12[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 40)           0           lstm_12[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 40)       1600        lstm_12[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 40)           0           lstm_12[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 80)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 40)           3200        attention_output[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 70)           2870        attention_vector[0][0]
# ==================================================================================================
# Total params: 137,110
# Trainable params: 137,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  75 / 186
# Exact representations :  70 / 186
# MSE on test :  0.015116497979159918
# RMSE on test :  0.12294916827355896
#
# Epoch 00001: val_loss improved from inf to 0.01512, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 9s - loss: 0.0206 - val_loss: 0.0151
# Epoch 2/70
# Valid representations :  130 / 186
# Exact representations :  105 / 186
# MSE on test :  0.01141464858451797
# RMSE on test :  0.10683935877998318
#
# Epoch 00002: val_loss improved from 0.01512 to 0.01141, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0143 - val_loss: 0.0114
# Epoch 3/70
# Valid representations :  143 / 186
# Exact representations :  128 / 186
# MSE on test :  0.008981847237315177
# RMSE on test :  0.0947726080537788
#
# Epoch 00003: val_loss improved from 0.01141 to 0.00898, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0114 - val_loss: 0.0090
# Epoch 4/70
# Valid representations :  151 / 186
# Exact representations :  137 / 186
# MSE on test :  0.007977196675493708
# RMSE on test :  0.08931515367222803
#
# Epoch 00004: val_loss improved from 0.00898 to 0.00798, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0099 - val_loss: 0.0080
# Epoch 5/70
# Valid representations :  153 / 186
# Exact representations :  142 / 186
# MSE on test :  0.00729287609037244
# RMSE on test :  0.08539833774946934
#
# Epoch 00005: val_loss improved from 0.00798 to 0.00729, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0090 - val_loss: 0.0073
# Epoch 6/70
# Valid representations :  154 / 186
# Exact representations :  143 / 186
# MSE on test :  0.0069776650619611325
# RMSE on test :  0.08353241922727446
#
# Epoch 00006: val_loss improved from 0.00729 to 0.00698, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0083 - val_loss: 0.0070
# Epoch 7/70
# Valid representations :  155 / 186
# Exact representations :  146 / 186
# MSE on test :  0.006351887360211504
# RMSE on test :  0.07969872872393577
#
# Epoch 00007: val_loss improved from 0.00698 to 0.00635, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 8s - loss: 0.0077 - val_loss: 0.0064
# Epoch 8/70
# Valid representations :  160 / 186
# Exact representations :  147 / 186
# MSE on test :  0.005724808605892002
# RMSE on test :  0.07566246497367107
#
# Epoch 00008: val_loss improved from 0.00635 to 0.00572, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0072 - val_loss: 0.0057
# Epoch 9/70
# Valid representations :  162 / 186
# Exact representations :  150 / 186
# MSE on test :  0.005444300967196888
# RMSE on test :  0.0737855064846538
#
# Epoch 00009: val_loss improved from 0.00572 to 0.00544, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0066 - val_loss: 0.0054
# Epoch 10/70
# Valid representations :  162 / 186
# Exact representations :  155 / 186
# MSE on test :  0.005298218756758619
# RMSE on test :  0.07278886423594352
#
# Epoch 00010: val_loss improved from 0.00544 to 0.00530, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0062 - val_loss: 0.0053
# Epoch 11/70
# Valid representations :  162 / 186
# Exact representations :  153 / 186
# MSE on test :  0.005200363663323188
# RMSE on test :  0.07211354701665415
#
# Epoch 00011: val_loss improved from 0.00530 to 0.00520, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0058 - val_loss: 0.0052
# Epoch 12/70
# Valid representations :  162 / 186
# Exact representations :  155 / 186
# MSE on test :  0.005255133583362238
# RMSE on test :  0.07249230016603307
#
# Epoch 00012: val_loss did not improve from 0.00520
# 496/496 - 7s - loss: 0.0056 - val_loss: 0.0053
# Epoch 13/70
# Valid representations :  163 / 186
# Exact representations :  155 / 186
# MSE on test :  0.004803580176822284
# RMSE on test :  0.06930786518730962
#
# Epoch 00013: val_loss improved from 0.00520 to 0.00480, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0051 - val_loss: 0.0048
# Epoch 14/70
# Valid representations :  163 / 186
# Exact representations :  155 / 186
# MSE on test :  0.00485217685082574
# RMSE on test :  0.06965756851072065
#
# Epoch 00014: val_loss did not improve from 0.00480
# 496/496 - 7s - loss: 0.0049 - val_loss: 0.0049
# Epoch 15/70
# Valid representations :  166 / 186
# Exact representations :  160 / 186
# MSE on test :  0.0047402753222026
# RMSE on test :  0.06884965738623977
#
# Epoch 00015: val_loss improved from 0.00480 to 0.00474, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0047 - val_loss: 0.0047
# Epoch 16/70
# Valid representations :  165 / 186
# Exact representations :  157 / 186
# MSE on test :  0.004529509940472611
# RMSE on test :  0.06730163401042066
#
# Epoch 00016: val_loss improved from 0.00474 to 0.00453, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0044 - val_loss: 0.0045
# Epoch 17/70
# Valid representations :  166 / 186
# Exact representations :  160 / 186
# MSE on test :  0.004109090886083049
# RMSE on test :  0.06410219096164381
#
# Epoch 00017: val_loss improved from 0.00453 to 0.00411, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0041 - val_loss: 0.0041
# Epoch 18/70
# Valid representations :  169 / 186
# Exact representations :  160 / 186
# MSE on test :  0.004335639013335571
# RMSE on test :  0.06584556942828858
#
# Epoch 00018: val_loss did not improve from 0.00411
# 496/496 - 7s - loss: 0.0040 - val_loss: 0.0043
# Epoch 19/70
# Valid representations :  166 / 186
# Exact representations :  160 / 186
# MSE on test :  0.004127666680082313
# RMSE on test :  0.06424691961551396
#
# Epoch 00019: val_loss did not improve from 0.00411
# 496/496 - 7s - loss: 0.0037 - val_loss: 0.0041
# Epoch 20/70
# Valid representations :  168 / 186
# Exact representations :  161 / 186
# MSE on test :  0.003951903230817795
# RMSE on test :  0.06286416491784326
#
# Epoch 00020: val_loss improved from 0.00411 to 0.00395, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0036 - val_loss: 0.0040
# Epoch 21/70
# Valid representations :  169 / 186
# Exact representations :  166 / 186
# MSE on test :  0.003764545069078451
# RMSE on test :  0.061355888625937535
#
# Epoch 00021: val_loss improved from 0.00395 to 0.00376, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0035 - val_loss: 0.0038
# Epoch 22/70
# Valid representations :  168 / 186
# Exact representations :  156 / 186
# MSE on test :  0.004164495240618746
# RMSE on test :  0.06453290045100055
#
# Epoch 00022: val_loss did not improve from 0.00376
# 496/496 - 7s - loss: 0.0034 - val_loss: 0.0042
# Epoch 23/70
# Valid representations :  168 / 186
# Exact representations :  162 / 186
# MSE on test :  0.0036608601511820722
# RMSE on test :  0.0605050423616253
#
# Epoch 00023: val_loss improved from 0.00376 to 0.00366, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0032 - val_loss: 0.0037
# Epoch 24/70
# Valid representations :  168 / 186
# Exact representations :  163 / 186
# MSE on test :  0.0037292064810981987
# RMSE on test :  0.06106722919126263
#
# Epoch 00024: val_loss did not improve from 0.00366
# 496/496 - 7s - loss: 0.0032 - val_loss: 0.0037
# Epoch 25/70
# Valid representations :  167 / 186
# Exact representations :  161 / 186
# MSE on test :  0.0036579266498794815
# RMSE on test :  0.060480795711361814
#
# Epoch 00025: val_loss improved from 0.00366 to 0.00366, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0030 - val_loss: 0.0037
# Epoch 26/70
# Valid representations :  169 / 186
# Exact representations :  164 / 186
# MSE on test :  0.003297476166821448
# RMSE on test :  0.05742365511547874
#
# Epoch 00026: val_loss improved from 0.00366 to 0.00330, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0029 - val_loss: 0.0033
# Epoch 27/70
# Valid representations :  167 / 186
# Exact representations :  163 / 186
# MSE on test :  0.00329625404749368
# RMSE on test :  0.05741301287594721
#
# Epoch 00027: val_loss improved from 0.00330 to 0.00330, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0028 - val_loss: 0.0033
# Epoch 28/70
# Valid representations :  168 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0034422066991803904
# RMSE on test :  0.058670322132918194
#
# Epoch 00028: val_loss did not improve from 0.00330
# 496/496 - 7s - loss: 0.0029 - val_loss: 0.0034
# Epoch 29/70
# Valid representations :  167 / 186
# Exact representations :  162 / 186
# MSE on test :  0.0033791601850402374
# RMSE on test :  0.05813054433806927
#
# Epoch 00029: val_loss did not improve from 0.00330
# 496/496 - 7s - loss: 0.0027 - val_loss: 0.0034
# Epoch 30/70
# Valid representations :  169 / 186
# Exact representations :  164 / 186
# MSE on test :  0.003178411927755547
# RMSE on test :  0.05637740618151519
#
# Epoch 00030: val_loss improved from 0.00330 to 0.00318, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0026 - val_loss: 0.0032
# Epoch 31/70
# Valid representations :  168 / 186
# Exact representations :  164 / 186
# MSE on test :  0.003038379994812284
# RMSE on test :  0.05512150210954237
#
# Epoch 00031: val_loss improved from 0.00318 to 0.00304, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0026 - val_loss: 0.0030
# Epoch 32/70
# Valid representations :  167 / 186
# Exact representations :  165 / 186
# MSE on test :  0.0031603007932450877
# RMSE on test :  0.05621655266240618
#
# Epoch 00032: val_loss did not improve from 0.00304
# 496/496 - 7s - loss: 0.0025 - val_loss: 0.0032
# Epoch 33/70
# Valid representations :  167 / 186
# Exact representations :  163 / 186
# MSE on test :  0.0030148025321014935
# RMSE on test :  0.054907217486424256
#
# Epoch 00033: val_loss improved from 0.00304 to 0.00301, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0025 - val_loss: 0.0030
# Epoch 34/70
# Valid representations :  169 / 186
# Exact representations :  165 / 186
# MSE on test :  0.002969563832597106
# RMSE on test :  0.05449370452260615
#
# Epoch 00034: val_loss improved from 0.00301 to 0.00297, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0024 - val_loss: 0.0030
# Epoch 35/70
# Valid representations :  167 / 186
# Exact representations :  165 / 186
# MSE on test :  0.0029783770095118648
# RMSE on test :  0.05457450878855315
#
# Epoch 00035: val_loss did not improve from 0.00297
# 496/496 - 7s - loss: 0.0023 - val_loss: 0.0030
# Epoch 36/70
# Valid representations :  168 / 186
# Exact representations :  166 / 186
# MSE on test :  0.0030040225405985185
# RMSE on test :  0.0548089640533236
#
# Epoch 00036: val_loss did not improve from 0.00297
# 496/496 - 7s - loss: 0.0023 - val_loss: 0.0030
# Epoch 37/70
# Valid representations :  168 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0029557323291047434
# RMSE on test :  0.05436664721228212
#
# Epoch 00037: val_loss improved from 0.00297 to 0.00296, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0024 - val_loss: 0.0030
# Epoch 38/70
# Valid representations :  168 / 186
# Exact representations :  166 / 186
# MSE on test :  0.0028473020978342476
# RMSE on test :  0.05336011710851324
#
# Epoch 00038: val_loss improved from 0.00296 to 0.00285, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 8s - loss: 0.0022 - val_loss: 0.0028
# Epoch 39/70
# Valid representations :  168 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0028354561626400474
# RMSE on test :  0.0532490015177754
#
# Epoch 00039: val_loss improved from 0.00285 to 0.00284, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0021 - val_loss: 0.0028
# Epoch 40/70
# Valid representations :  171 / 186
# Exact representations :  166 / 186
# MSE on test :  0.002843117399024899
# RMSE on test :  0.0533208908311264
#
# Epoch 00040: val_loss did not improve from 0.00284
# 496/496 - 7s - loss: 0.0021 - val_loss: 0.0028
# Epoch 41/70
# Valid representations :  168 / 186
# Exact representations :  163 / 186
# MSE on test :  0.0028194691289116394
# RMSE on test :  0.053098673513673006
#
# Epoch 00041: val_loss improved from 0.00284 to 0.00282, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0020 - val_loss: 0.0028
# Epoch 42/70
# Valid representations :  169 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0026913185277530555
# RMSE on test :  0.05187791946245585
#
# Epoch 00042: val_loss improved from 0.00282 to 0.00269, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0020 - val_loss: 0.0027
# Epoch 43/70
# Valid representations :  170 / 186
# Exact representations :  165 / 186
# MSE on test :  0.002580773382724441
# RMSE on test :  0.05080131280512779
#
# Epoch 00043: val_loss improved from 0.00269 to 0.00258, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0020 - val_loss: 0.0026
# Epoch 44/70
# Valid representations :  170 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0027711408847217608
# RMSE on test :  0.05264162691940439
#
# Epoch 00044: val_loss did not improve from 0.00258
# 496/496 - 7s - loss: 0.0019 - val_loss: 0.0028
# Epoch 45/70
# Valid representations :  172 / 186
# Exact representations :  167 / 186
# MSE on test :  0.002958481047022739
# RMSE on test :  0.05439192078813487
#
# Epoch 00045: val_loss did not improve from 0.00258
# 496/496 - 7s - loss: 0.0019 - val_loss: 0.0030
# Epoch 46/70
# Valid representations :  169 / 186
# Exact representations :  168 / 186
# MSE on test :  0.002612583300729806
# RMSE on test :  0.051113435618531905
#
# Epoch 00046: val_loss did not improve from 0.00258
# 496/496 - 7s - loss: 0.0019 - val_loss: 0.0026
# Epoch 47/70
# Valid representations :  167 / 186
# Exact representations :  163 / 186
# MSE on test :  0.002570792683908764
# RMSE on test :  0.05070298496054018
#
# Epoch 00047: val_loss improved from 0.00258 to 0.00257, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0019 - val_loss: 0.0026
# Epoch 48/70
# Valid representations :  171 / 186
# Exact representations :  169 / 186
# MSE on test :  0.0025793467335292475
# RMSE on test :  0.05078726940414544
#
# Epoch 00048: val_loss did not improve from 0.00257
# 496/496 - 7s - loss: 0.0019 - val_loss: 0.0026
# Epoch 49/70
# Valid representations :  169 / 186
# Exact representations :  166 / 186
# MSE on test :  0.0026519929869727307
# RMSE on test :  0.05149750466743734
#
# Epoch 00049: val_loss did not improve from 0.00257
# 496/496 - 7s - loss: 0.0017 - val_loss: 0.0027
# Epoch 50/70
# Valid representations :  168 / 186
# Exact representations :  167 / 186
# MSE on test :  0.0025412477222861354
# RMSE on test :  0.0504107897407503
#
# Epoch 00050: val_loss improved from 0.00257 to 0.00254, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0018 - val_loss: 0.0025
# Epoch 51/70
# Valid representations :  171 / 186
# Exact representations :  168 / 186
# MSE on test :  0.0026514558489420543
# RMSE on test :  0.05149228921830971
#
# Epoch 00051: val_loss did not improve from 0.00254
# 496/496 - 7s - loss: 0.0017 - val_loss: 0.0027
# Epoch 52/70
# Valid representations :  171 / 186
# Exact representations :  167 / 186
# MSE on test :  0.0027074512767187747
# RMSE on test :  0.05203317477070542
#
# Epoch 00052: val_loss did not improve from 0.00254
# 496/496 - 7s - loss: 0.0017 - val_loss: 0.0027
# Epoch 53/70
# Valid representations :  170 / 186
# Exact representations :  167 / 186
# MSE on test :  0.002588113380553718
# RMSE on test :  0.05087350371808214
#
# Epoch 00053: val_loss did not improve from 0.00254
# 496/496 - 7s - loss: 0.0017 - val_loss: 0.0026
# Epoch 54/70
# Valid representations :  174 / 186
# Exact representations :  168 / 186
# MSE on test :  0.00235684314292838
# RMSE on test :  0.04854732889591744
#
# Epoch 00054: val_loss improved from 0.00254 to 0.00236, saving model to saved_LSTM/best_model0.8069751272838444.hdf5
# 496/496 - 7s - loss: 0.0017 - val_loss: 0.0024
# Epoch 55/70
# Valid representations :  171 / 186
# Exact representations :  169 / 186
# MSE on test :  0.0026076274333670913
# RMSE on test :  0.05106493350007509
#
# Epoch 00055: val_loss did not improve from 0.00236
# 496/496 - 7s - loss: 0.0016 - val_loss: 0.0026
# Epoch 56/70
# Valid representations :  172 / 186
# Exact representations :  168 / 186
# MSE on test :  0.0026984743931477637
# RMSE on test :  0.05194684199398231
#
# Epoch 00056: val_loss did not improve from 0.00236
# 496/496 - 7s - loss: 0.0016 - val_loss: 0.0027
# Epoch 57/70
# Valid representations :  171 / 186
# Exact representations :  167 / 186
# MSE on test :  0.002475402969196195
# RMSE on test :  0.04975342168329928
#
# Epoch 00057: val_loss did not improve from 0.00236
# 496/496 - 7s - loss: 0.0016 - val_loss: 0.0025
# Epoch 58/70
# Valid representations :  169 / 186
# Exact representations :  165 / 186
# MSE on test :  0.0024472649207474026
# RMSE on test :  0.04946983849526298
#
# Epoch 00058: val_loss did not improve from 0.00236
# 496/496 - 7s - loss: 0.0015 - val_loss: 0.0024
# Epoch 59/70
# Valid representations :  170 / 186
# Exact representations :  166 / 186
# MSE on test :  0.0024206522453175793
# RMSE on test :  0.04920012444412696
#
# Epoch 00059: val_loss did not improve from 0.00236
# 496/496 - 7s - loss: 0.0016 - val_loss: 0.0024
# Epoch 00059: early stopping
# End of training !
# CPU Time to train :  1460.814853666001
# Testing on test set ...
# Valid representations :  978 / 1100
# Exact representations :  933 / 1100
# MSE on test :  0.0033916957907653956
# RMSE on test :  0.05823826740868409
# Testing on training set ...
# Valid representations :  933 / 991
# Exact representations :  930 / 991
# MSE on test :  0.0011346798740557082
# RMSE on test :  0.03368500963419349
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Model: "model_27"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_13 (Masking)            (None, 54, 768)      0           input_14[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  [(None, 54, 40), (No 129440      masking_13[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 40)           0           lstm_13[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 40)       1600        lstm_13[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 40)           0           lstm_13[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 80)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 40)           3200        attention_output[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 70)           2870        attention_vector[0][0]
# ==================================================================================================
# Total params: 137,110
# Trainable params: 137,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# model for hidden states:  None
# Model: "model_26"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_13 (Masking)            (None, 54, 768)      0           input_14[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  [(None, 54, 40), (No 129440      masking_13[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 40)           0           lstm_13[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 40)       1600        lstm_13[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 40)           0           lstm_13[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 80)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 40)           3200        attention_output[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 70)           2870        attention_vector[0][0]
# ==================================================================================================
# Total params: 137,110
# Trainable params: 137,110
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  65 / 186
# Exact representations :  62 / 186
# MSE on test :  0.015566749079127397
# RMSE on test :  0.12476677874789986
#
# Epoch 00001: val_loss improved from inf to 0.01557, saving model to saved_LSTM/best_model0.6900841051557363.hdf5
# 496/496 - 9s - loss: 0.0211 - val_loss: 0.0156
# Epoch 2/70
# Valid representations :  130 / 186
# Exact representations :  104 / 186
# MSE on test :  0.011279685715658976
# RMSE on test :  0.10620586478937487
#
# Epoch 00002: val_loss improved from 0.01557 to 0.01128, saving model to saved_LSTM/best_model0.6900841051557363.hdf5
# 496/496 - 7s - loss: 0.0146 - val_loss: 0.0113
# Epoch 3/70
# Valid representations :  139 / 186
# Exact representations :  122 / 186
# MSE on test :  0.009588726058044922
# RMSE on test :  0.09792204071630106
#
# Epoch 00003: val_loss improved from 0.01128 to 0.00959, saving model to saved_LSTM/best_model0.6900841051557363.hdf5
# 496/496 - 7s - loss: 0.0118 - val_loss: 0.0096
# Epoch 4/70
# Valid representations :  151 / 186
# Exact representations :  135 / 186
# MSE on test :  0.008562046743558368
# RMSE on test :  0.09253132844371342
#
# Epoch 00004: val_loss improved from 0.00959 to 0.00856, saving model to saved_LSTM/best_model0.6900841051557363.hdf5
# 496/496 - 7s - loss: 0.0103 - val_loss: 0.0086
# Epoch 5/70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-fb2c1d34e111> in <module>
#      49                     model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
#      50                 else:
# ---> 51                     model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))
#      52
#      53
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
lstm_units = 80
for _ in np.arange(1):
    if __name__ == "__main__":
        for i in np.arange(1):
            if use_save_version:
                model = keras.models.load_model(path + "best_model"+rand_id+".hdf5")
                if test_version:
                    model_for_test = keras.models.load_model(path + "best_model_for_test"+rand_id+".hdf5")

            else:
                rand_id = str(np.random.random()) #random id used for the file names during the model save

                #build the model
                if test_version:
                    inp = Input((max_seq_len, nb_unique_words))
                    masked = Masking(mask_value=special_value)(inp)
                    lstm_out, state_h, state_c = LSTM(lstm_units, return_state = True, return_sequences=True, dropout = dropout)(masked)
                    attention_weights, attention_output = Attention(80)(lstm_out)
                    output_to_train = Dense(output_size)(attention_output)

                    model = Model(inputs = inp, outputs = output_to_train)
                    model_for_test = Model(inputs = inp, outputs = [output_to_train, state_h, state_c])
                    model.compile(loss='mean_squared_error', optimizer='adam')
                    model_for_test.compile(loss='mean_squared_error', optimizer='adam')

                    if verbose_training:
                        print("model for hidden states: ", model_for_test.summary())
                else:
                    model = Sequential()
                    model.add(Masking(mask_value=special_value, input_shape=(max_seq_len, nb_unique_words)))
                    model.add(LSTM(lstm_units, stateful=False))
                    model.add(Dense(output_size))
                    model.compile(loss='mean_squared_error', optimizer='adam')

                if verbose_training:
                    print(model.summary()) # print the architecture of the model

                if not(minimal_mode):
                    history = LossHistory() #to get the evolution of the loss during training
                    checkpoint = ModelCheckpoint("saved_LSTM/best_model"+rand_id+".hdf5",
                                                monitor='val_loss', verbose=1,
                                                mode='auto', period=1, save_best_only = True) #we save the model after each epoch of training
                    earlystopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

                t1 = time.process_time()

                #training
                if minimal_mode:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)
                else:
                    model.fit(trainX_pad, trainY, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, callbacks=[history, checkpoint, earlystopping], validation_data=(validationX_pad, validationY))


                t2 = time.process_time()

                if verbose_training:
                    print("End of training !")
                    print("CPU Time to train : ", t2 -t1)
                if not(minimal_mode):
                    model_for_test.save("saved_LSTM/best_model_for_test"+rand_id+".hdf5")
                    history.plot_loss()


            if verbose_training:
                print("Testing on test set ...")
            v, ex, er = test_on_test_set(model, testX_pad[0:1100] , testY[0:1100], test_sentences[0:1100], verbose_training, threshold_factor)
            if minimal_mode:
                print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

            if not(minimal_mode):
                if verbose_training:
                    print("Testing on training set ...")
                v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


            #qualitative analysis of the output of the LSTM
            if not(minimal_mode):
                test_sent = ["BEGIN on the middle is a green glass and that is a orange bowl END", #0
                "BEGIN and on the middle is a green glass and that is a orange bowl END",
                "BEGIN a blue bowl is on the right and on the right there is the blue bowl END",
                "BEGIN on the middle there is the orange and the orange on the middle is orange END", #3
                "BEGIN the orange is orange and on the middle there is the green cup END",
                "BEGIN on the left there is a blue glass and this is a orange END",
                "BEGIN the glass on the left is blue and the bowl on the right is green END", #6
                "BEGIN the orange on the right is green and there is a blue cup on the middle END",
                "BEGIN on the right there is a red glass and the cup on the middle is red END",
                "BEGIN a green glass is on the right and on the left is a orange END"] #9

                #plot the final outputs on a test sentence
                outputs = test_with_sentences(test_sent , model)
                ind = i
                plot_final_activation(outputs[ind],
                                    concepts_delimitations,
                                    output_id_to_concept_dict,
                                    nb_concepts,
                                    test_sent[ind])

                #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
                s = test_sent[ind]
                suc_outputs = get_successive_outputs(s, model)
                plot_concept_activation(s,
                                        suc_outputs,
                                        concepts_delimitations,
                                        nb_concepts,
                                        savefig = True,
                                        sub_ttl_fig = s + " LSTM")


                #plot the evolution of cell activity
                activations = get_successive_outputs(s, model_for_test)
                plot_hidden_states(s,
                                model_for_test,
                                units_to_plot = 'all',
                                state = 'cell',
                                plt_var = True,
                                plt_sum = False)
# Out:
# Model: "model_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_11 (Masking)            (None, 54, 768)      0           input_12[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, 54, 80), (No 271680      masking_11[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 80)           0           lstm_11[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 80)       6400        lstm_11[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 80)           0           lstm_11[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 160)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 80)           12800       attention_output[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 70)           5670        attention_vector[0][0]
# ==================================================================================================
# Total params: 296,550
# Trainable params: 296,550
# Non-trainable params: 0
# __________________________________________________________________________________________________
# model for hidden states:  None
# Model: "model_22"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 54, 768)]    0
# __________________________________________________________________________________________________
# masking_11 (Masking)            (None, 54, 768)      0           input_12[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, 54, 80), (No 271680      masking_11[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 80)           0           lstm_11[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 54, 80)       6400        lstm_11[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 54)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 54)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 80)           0           lstm_11[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 160)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 80)           12800       attention_output[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 70)           5670        attention_vector[0][0]
# ==================================================================================================
# Total params: 296,550
# Trainable params: 296,550
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/70
# Valid representations :  100 / 186
# Exact representations :  88 / 186
# MSE on test :  0.013981263830305343
# RMSE on test :  0.118242394386723
#
# Epoch 00001: val_loss improved from inf to 0.01398, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 10s - loss: 0.0198 - val_loss: 0.0140
# Epoch 2/70
# Valid representations :  134 / 186
# Exact representations :  116 / 186
# MSE on test :  0.01026984149118987
# RMSE on test :  0.101340226421643
#
# Epoch 00002: val_loss improved from 0.01398 to 0.01027, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0131 - val_loss: 0.0103
# Epoch 3/70
# Valid representations :  140 / 186
# Exact representations :  125 / 186
# MSE on test :  0.008639146985798258
# RMSE on test :  0.09294701170988907
#
# Epoch 00003: val_loss improved from 0.01027 to 0.00864, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0107 - val_loss: 0.0086
# Epoch 4/70
# Valid representations :  153 / 186
# Exact representations :  142 / 186
# MSE on test :  0.007051981857722767
# RMSE on test :  0.0839760790804308
#
# Epoch 00004: val_loss improved from 0.00864 to 0.00705, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0092 - val_loss: 0.0071
# Epoch 5/70
# Valid representations :  159 / 186
# Exact representations :  144 / 186
# MSE on test :  0.006201795847291304
# RMSE on test :  0.07875148155616696
#
# Epoch 00005: val_loss improved from 0.00705 to 0.00620, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0080 - val_loss: 0.0062
# Epoch 6/70
# Valid representations :  163 / 186
# Exact representations :  147 / 186
# MSE on test :  0.005667947582017248
# RMSE on test :  0.07528577277293
#
# Epoch 00006: val_loss improved from 0.00620 to 0.00567, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0070 - val_loss: 0.0057
# Epoch 7/70
# Valid representations :  164 / 186
# Exact representations :  153 / 186
# MSE on test :  0.0052177568789360754
# RMSE on test :  0.07223404238263338
#
# Epoch 00007: val_loss improved from 0.00567 to 0.00522, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0062 - val_loss: 0.0052
# Epoch 8/70
# Valid representations :  166 / 186
# Exact representations :  156 / 186
# MSE on test :  0.005053179450746453
# RMSE on test :  0.07108571903516524
#
# Epoch 00008: val_loss improved from 0.00522 to 0.00505, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0055 - val_loss: 0.0051
# Epoch 9/70
# Valid representations :  169 / 186
# Exact representations :  155 / 186
# MSE on test :  0.004775012674326297
# RMSE on test :  0.0691014665135719
#
# Epoch 00009: val_loss improved from 0.00505 to 0.00478, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0051 - val_loss: 0.0048
# Epoch 10/70
# Valid representations :  166 / 186
# Exact representations :  157 / 186
# MSE on test :  0.004644758061893057
# RMSE on test :  0.06815246189165185
#
# Epoch 00010: val_loss improved from 0.00478 to 0.00464, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0046 - val_loss: 0.0046
# Epoch 11/70
# Valid representations :  167 / 186
# Exact representations :  154 / 186
# MSE on test :  0.004642173005112295
# RMSE on test :  0.06813349400340697
#
# Epoch 00011: val_loss improved from 0.00464 to 0.00464, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0042 - val_loss: 0.0046
# Epoch 12/70
# Valid representations :  167 / 186
# Exact representations :  157 / 186
# MSE on test :  0.004258279944900803
# RMSE on test :  0.06525549743049089
#
# Epoch 00012: val_loss improved from 0.00464 to 0.00426, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0039 - val_loss: 0.0043
# Epoch 13/70
# Valid representations :  166 / 186
# Exact representations :  161 / 186
# MSE on test :  0.003975431957852229
# RMSE on test :  0.0630510266201291
#
# Epoch 00013: val_loss improved from 0.00426 to 0.00398, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0036 - val_loss: 0.0040
# Epoch 14/70
# Valid representations :  166 / 186
# Exact representations :  154 / 186
# MSE on test :  0.0038070086492139033
# RMSE on test :  0.06170096149343139
#
# Epoch 00014: val_loss improved from 0.00398 to 0.00381, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0035 - val_loss: 0.0038
# Epoch 15/70
# Valid representations :  171 / 186
# Exact representations :  165 / 186
# MSE on test :  0.0035909015545260168
# RMSE on test :  0.05992413165433452
#
# Epoch 00015: val_loss improved from 0.00381 to 0.00359, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0032 - val_loss: 0.0036
# Epoch 16/70
# Valid representations :  171 / 186
# Exact representations :  163 / 186
# MSE on test :  0.0033707801415455174
# RMSE on test :  0.05805842007448633
#
# Epoch 00016: val_loss improved from 0.00359 to 0.00337, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0030 - val_loss: 0.0034
# Epoch 17/70
# Valid representations :  171 / 186
# Exact representations :  162 / 186
# MSE on test :  0.0031090558019766196
# RMSE on test :  0.055758907826253375
#
# Epoch 00017: val_loss improved from 0.00337 to 0.00311, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0029 - val_loss: 0.0031
# Epoch 18/70
# Valid representations :  169 / 186
# Exact representations :  164 / 186
# MSE on test :  0.003352297632094825
# RMSE on test :  0.05789902962999315
#
# Epoch 00018: val_loss did not improve from 0.00311
# 496/496 - 8s - loss: 0.0026 - val_loss: 0.0034
# Epoch 19/70
# Valid representations :  170 / 186
# Exact representations :  162 / 186
# MSE on test :  0.0031820356107441637
# RMSE on test :  0.0564095347502899
#
# Epoch 00019: val_loss did not improve from 0.00311
# 496/496 - 8s - loss: 0.0026 - val_loss: 0.0032
# Epoch 20/70
# Valid representations :  172 / 186
# Exact representations :  161 / 186
# MSE on test :  0.0033520669009445476
# RMSE on test :  0.057897037065333036
#
# Epoch 00020: val_loss did not improve from 0.00311
# 496/496 - 8s - loss: 0.0023 - val_loss: 0.0034
# Epoch 21/70
# Valid representations :  171 / 186
# Exact representations :  162 / 186
# MSE on test :  0.003112871949998737
# RMSE on test :  0.05579311740706677
#
# Epoch 00021: val_loss did not improve from 0.00311
# 496/496 - 8s - loss: 0.0023 - val_loss: 0.0031
# Epoch 22/70
# Valid representations :  170 / 186
# Exact representations :  164 / 186
# MSE on test :  0.002809815088267122
# RMSE on test :  0.05300768895421797
#
# Epoch 00022: val_loss improved from 0.00311 to 0.00281, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0021 - val_loss: 0.0028
# Epoch 23/70
# Valid representations :  169 / 186
# Exact representations :  160 / 186
# MSE on test :  0.002948236268738032
# RMSE on test :  0.05429766356610598
#
# Epoch 00023: val_loss did not improve from 0.00281
# 496/496 - 8s - loss: 0.0020 - val_loss: 0.0029
# Epoch 24/70
# Valid representations :  169 / 186
# Exact representations :  166 / 186
# MSE on test :  0.002639786261859572
# RMSE on test :  0.05137885033610203
#
# Epoch 00024: val_loss improved from 0.00281 to 0.00264, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0019 - val_loss: 0.0026
# Epoch 25/70
# Valid representations :  172 / 186
# Exact representations :  167 / 186
# MSE on test :  0.0026421871982412475
# RMSE on test :  0.05140221005211009
#
# Epoch 00025: val_loss did not improve from 0.00264
# 496/496 - 8s - loss: 0.0018 - val_loss: 0.0026
# Epoch 26/70
# Valid representations :  172 / 186
# Exact representations :  165 / 186
# MSE on test :  0.002549988697350119
# RMSE on test :  0.05049741277877629
#
# Epoch 00026: val_loss improved from 0.00264 to 0.00255, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0017 - val_loss: 0.0025
# Epoch 27/70
# Valid representations :  172 / 186
# Exact representations :  167 / 186
# MSE on test :  0.002518587267237738
# RMSE on test :  0.05018552846426685
#
# Epoch 00027: val_loss improved from 0.00255 to 0.00252, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0016 - val_loss: 0.0025
# Epoch 28/70
# Valid representations :  171 / 186
# Exact representations :  164 / 186
# MSE on test :  0.002590857661976008
# RMSE on test :  0.050900468190145445
#
# Epoch 00028: val_loss did not improve from 0.00252
# 496/496 - 8s - loss: 0.0018 - val_loss: 0.0026
# Epoch 29/70
# Valid representations :  171 / 186
# Exact representations :  166 / 186
# MSE on test :  0.002534445010018497
# RMSE on test :  0.050343271745273935
#
# Epoch 00029: val_loss did not improve from 0.00252
# 496/496 - 8s - loss: 0.0016 - val_loss: 0.0025
# Epoch 30/70
# Valid representations :  172 / 186
# Exact representations :  164 / 186
# MSE on test :  0.002407004089636545
# RMSE on test :  0.049061227967067286
#
# Epoch 00030: val_loss improved from 0.00252 to 0.00241, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0015 - val_loss: 0.0024
# Epoch 31/70
# Valid representations :  172 / 186
# Exact representations :  168 / 186
# MSE on test :  0.002190082653148453
# RMSE on test :  0.04679831891370088
#
# Epoch 00031: val_loss improved from 0.00241 to 0.00219, saving model to saved_LSTM/best_model0.4984911780501633.hdf5
# 496/496 - 8s - loss: 0.0015 - val_loss: 0.0022
# Epoch 32/70
# Valid representations :  171 / 186
# Exact representations :  163 / 186
# MSE on test :  0.002386614812270806
# RMSE on test :  0.04885299184564653
#
# Epoch 00032: val_loss did not improve from 0.00219
# 496/496 - 8s - loss: 0.0013 - val_loss: 0.0024
# Epoch 33/70
# Valid representations :  171 / 186
# Exact representations :  163 / 186
# MSE on test :  0.002541197622276463
# RMSE on test :  0.05041029282077682
#
# Epoch 00033: val_loss did not improve from 0.00219
# 496/496 - 8s - loss: 0.0013 - val_loss: 0.0025
# Epoch 34/70
# Valid representations :  171 / 186
# Exact representations :  165 / 186
# MSE on test :  0.002197899041726266
# RMSE on test :  0.046881755958221805
#
# Epoch 00034: val_loss did not improve from 0.00219
# 496/496 - 8s - loss: 0.0012 - val_loss: 0.0022
# Epoch 35/70
# Valid representations :  172 / 186
# Exact representations :  166 / 186
# MSE on test :  0.002478091790578432
# RMSE on test :  0.04978043582149951
#
# Epoch 00035: val_loss did not improve from 0.00219
# 496/496 - 8s - loss: 0.0013 - val_loss: 0.0025
# Epoch 36/70
# Valid representations :  173 / 186
# Exact representations :  164 / 186
# MSE on test :  0.0022530930443093386
# RMSE on test :  0.0474667572550447
#
# Epoch 00036: val_loss did not improve from 0.00219
# 496/496 - 8s - loss: 0.0012 - val_loss: 0.0023
# Epoch 00036: early stopping
# End of training !
# CPU Time to train :  1478.2071685280025
# Testing on test set ...
# Valid representations :  988 / 1100
# Exact representations :  943 / 1100
# MSE on test :  0.003148986825152802
# RMSE on test :  0.05611583399676781
# Testing on training set ...
# Valid representations :  956 / 991
# Exact representations :  952 / 991
# MSE on test :  0.0008075819530460408
# RMSE on test :  0.02841798643546092
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# ['', 'BEGIN', 'BEGIN on', 'BEGIN on the', 'BEGIN on the middle', 'BEGIN on the middle is', 'BEGIN on the middle is a', 'BEGIN on the middle is a green', 'BEGIN on the middle is a green glass', 'BEGIN on the middle is a green glass and', 'BEGIN on the middle is a green glass and that', 'BEGIN on the middle is a green glass and that is', 'BEGIN on the middle is a green glass and that is a', 'BEGIN on the middle is a green glass and that is a orange', 'BEGIN on the middle is a green glass and that is a orange bowl', 'BEGIN on the middle is a green glass and that is a orange bowl END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#from keras.models import load_model
#model_for_test = load_model("saved_LSTM/best_model_for_test0.012230777794171699.hdf5")
#model = load_model("saved_LSTM/best_model0.012230777794171699.hdf5")
#verbose_training = True
if verbose_training:
        print("Testing on test set ...")
        v, ex, er = test_on_test_set(model, testX_pad[0:250] , testY[0:250], test_sentences[0:250], verbose_training, threshold_factor)
        if minimal_mode:
            print(str(nb_objects) + "," +str(v) + "," + str(ex) + ","+ str(er) + "," + str(t2-t1))

        if not(minimal_mode):
            if verbose_training:
                print("Testing on training set ...")
            v, ex, er = test_on_test_set(model, trainX_pad , trainY, train_sentences, True, threshold_factor)


        #qualitative analysis of the output of the LSTM
        if not(minimal_mode):
            test_sent = ['BEGIN this is a yellow and black rubber hammer. END',
       'BEGIN a yellow bananna END',
       'BEGIN this is a small black flashlight with an attached cloth handle. END',
       'BEGIN the object is a lemon. it is uncut with a sticker still on the skin. END',
       'BEGIN this is a tub of toothpaste with a blue label. END',
       'BEGIN a green marker. END',
       'BEGIN it is a pair of blue and red pliers. END',
       'BEGIN it is a white led lightbulb. END',
       'BEGIN a small white onion. END',
       'BEGIN on the turntable is a metal hammer with a yellow and black plastic handle. END'] #9

            #plot the final outputs on a test sentence
            outputs = test_with_sentences(test_sent , model)
            ind = 0
            plot_final_activation(outputs[ind],
                                concepts_delimitations,
                                output_id_to_concept_dict,
                                nb_concepts,
                                test_sent[ind])

            #plot and save to png the evolution of the LSTM outputs during the processing of a sentence
            s = test_sent[ind]
            suc_outputs = get_successive_outputs(s, model)
            plot_concept_activation(s,
                                    suc_outputs,
                                    concepts_delimitations,
                                    nb_concepts,
                                    savefig = True,
                                    sub_ttl_fig = s + " LSTM")


            #plot the evolution of cell activity
            activations = get_successive_outputs(s, model_for_test)
            plot_hidden_states(s,
                            model_for_test,
                            units_to_plot = 'all',
                            state = 'cell',
                            plt_var = True,
                            plt_sum = False)
# Out:
# Testing on test set ...
# Valid representations :  236 / 250
# Exact representations :  228 / 250
# MSE on test :  0.00285707277210657
# RMSE on test :  0.053451592792980174
# Testing on training set ...
# Valid representations :  880 / 894
# Exact representations :  876 / 894
# MSE on test :  0.0007335568091795281
# RMSE on test :  0.02708425389741294
# ['', 'BEGIN', 'BEGIN this', 'BEGIN this is', 'BEGIN this is a', 'BEGIN this is a yellow', 'BEGIN this is a yellow and', 'BEGIN this is a yellow and black', 'BEGIN this is a yellow and black rubber', 'BEGIN this is a yellow and black rubber hammer.', 'BEGIN this is a yellow and black rubber hammer. END']
# ['', 'BEGIN', 'BEGIN this', 'BEGIN this is', 'BEGIN this is a', 'BEGIN this is a yellow', 'BEGIN this is a yellow and', 'BEGIN this is a yellow and black', 'BEGIN this is a yellow and black rubber', 'BEGIN this is a yellow and black rubber hammer.', 'BEGIN this is a yellow and black rubber hammer. END']
# ['', 'BEGIN', 'BEGIN this', 'BEGIN this is', 'BEGIN this is a', 'BEGIN this is a yellow', 'BEGIN this is a yellow and', 'BEGIN this is a yellow and black', 'BEGIN this is a yellow and black rubber', 'BEGIN this is a yellow and black rubber hammer.', 'BEGIN this is a yellow and black rubber hammer. END']
# /home/subbainria/Downloads/esn-vs-lstm-on-cross-situationnal-learning/plots.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def output_to_vision(output, nb_concepts, factor,
                     concepts_delimitations, output_id_to_concept_dict):
    objs = []
    nb_objects = 2
    for j in range(nb_objects):
        cat = [None] * 3
        offset = j*nb_concepts
        for i in range(len(concepts_delimitations)):
            cat_activations = output[offset+concepts_delimitations[i][0]:offset+concepts_delimitations[i][1]]
            proba = softmax(cat_activations)
            concept = np.argmax(proba)
            #the threshold to be accepted depend on the number of concept to choose from : must be a factor higher than the uniform proba
            threshold = factor / (concepts_delimitations[i][1] - concepts_delimitations[i][0])
            if proba[concept] < threshold:
                cat[i] = None
            else:
                cat[i] = output_id_to_concept_dict[concepts_delimitations[i][0] + concept]

        objs.append(RecognizedObject(cat[0], cat[1], cat[2])) #object, position, color

    return objs
